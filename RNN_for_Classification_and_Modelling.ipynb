# %%
## IMPORTS
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from collections import Counter
import nltk
nltk.download('punkt')
import random
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchtext
#glove = torchtext.vocab.GloVe(name="6B", dim=100, max_vectors=40000)

from google.colab import drive  
drive.mount('/content/drive/')
PATH = '/content/drive/My Drive/Colab/HW4/'
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Mounted at /content/drive/

# %%
print(torch.cuda.device_count())
print(torch.__version__)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
CUDA_LAUNCH_BLOCKING=1
# Out:
# 1
# 1.8.0+cu101
# cuda:0

# %% [markdown]
# **PROBLEM 2**

# %%
# create sequences of length 5 tokens
def create_seq(sent, max_len_seq = 5):
    sequences = []
    if len(sent) > max_len_seq: # if the number of tokens in 'text' is greater than 5
      for i in range(max_len_seq, len(sent)):
        seq = sent[i-max_len_seq:i+1] # select sequence of tokens
        #print("seq: {}".format(seq))
        sequences.append(seq) # add to the list
      return sequences
    else: # if the number of tokens in 'text' is equal to 5
      return [sent]
def split_sequences(text, max_len_seq):
    ## Sentences to sequences of max (sent dimension will be replaced by flattening obtaining only sequences)
    text = [create_seq(sent, max_len_seq) for sent in text]
    text = sum(text, []) # merge list-of-lists into a single list
    return text

def tokenize(text, eof_flag=True):
    ## Build words dictionary count
    words = Counter() #Dictionary that will map a word to the number of times it appeared in all the training sentences
    if eof_flag:
      for i, sentence in enumerate(text):
          text[i] = [] #The sentences will be stored as a list of words/tokens
          for word in nltk.word_tokenize(sentence): #Tokenizing the words
              word = word.lower().strip()
              words.update([word])
              text[i].append(word)
          text[i].insert(0,'<s>')
          text[i].append('</s>')
    else:
      for i, sentence in enumerate(text):
          text[i] = [] #The sentences will be stored as a list of words/tokens
          for word in sentence.split(): #Tokenizing the words
              word = word.lower().strip()
              words.update([word])
              text[i].append(word)
    return text, words


def encode_glove(words, eof_flag=True, file='glove_6B_100d.txt'):#glove.twitter.27B.100d
    ## Create glove structure from file
    glove = {}
    with open(PATH+file) as f: 
        for line in f:
            values = line.split()
            word = values[0]
            vector = np.asarray(values[1:], "float32")
            glove[word] = vector
    if eof_flag:
        to_add = ['_PAD','_UNK','<s>','</s>']
    else:
        to_add = ['_PAD','_UNK']
    for el in to_add:
        glove[el] = np.random.normal(scale=0.6, size=(100, )) #np.random.rand(100)
    ## Create embedding matrix for nn (based on the words in the vocab)
    matrix_len = len(words)
    weights_matrix = np.zeros((matrix_len, 100))
    words_found = 0
    for i, word in enumerate(words):
        try: 
            weights_matrix[i] = glove[word]
            words_found += 1
        except KeyError:
            weights_matrix[i] = np.random.normal(scale=0.6, size=(100, )) #np.random.rand(100)
    print("Word found in glove: {}/{}".format(words_found,matrix_len))
    return weights_matrix, glove

def encode(text, words, limit_appear=True, eof_flag=True):
    ## Removing the words that only appear once
    if limit_appear:
        words = {k:v for k,v in words.items() if v>1}
    else:
        words = {k:v for k,v in words.items() if v>0}
    words = sorted(words, key=words.get, reverse=True) # Sorting the words according to the number of appearances, with the most common word being first
    if eof_flag:
        to_add = ['_PAD','_UNK','<s>','</s>']
    else:
        to_add = ['_PAD','_UNK']
    words = to_add + words # Adding padding and unknown to our vocabulary so that they will be assigned an index
    word2idx = {o:i for i,o in enumerate(words)} # Dictionaries to store the word to index mappings and vice versa
    idx2word = {i:o for i,o in enumerate(words)}
    ## Encode text
    for i, sequence in enumerate(text):
        text[i] = [word2idx[word] if word in word2idx else word2idx['_UNK'] for word in sequence]
    return text, word2idx, idx2word, words

def pad_sequences(text, pad_token, max_len_seq):
    for i, sequence in enumerate(text): 
        if len(sequence) <= max_len_seq:
            for j in range(len(sequence), max_len_seq+1):
                text[i].insert(0,pad_token) #text[i].insert(0,0) #.append(0) # add to the list
    return text

def create_in_out(text):
    x = []
    y = []
    for seq in text:
      x.append([w for w in seq[:-1]])
      y.append([w for w in seq[1:]])
    text_train = np.asarray([np.asarray(s) for s in x])
    label_train = np.asarray([np.asarray(s) for s in y])
    return text_train, label_train


## Processing group
def test_processing(raw_text, max_len_seq, test_encode):
    text, words = tokenize(raw_text, eof_flag=False) ## Tokenize
    max_len_seq = len(max(text,key=len))
    print("\n---- Result after tokenization")
    print("Length words: {}".format(len(words)))
    print("words: {}".format(words))
    print("text: {}".format(text[0:2]))
    '''text = split_sequences(text, max_len_seq) ## Split in sequences
    print("\n---- Result after reorganizing by sequences")
    print("text: {}".format(text[0:2]))
    print("len(text): {}".format(len(text)))
    print("max_len_seq: {}".format(max_len_seq))'''
    for i, sent in enumerate(text):
        text[i] = [test_encode[word] if word in test_encode else test_encode['_UNK'] for word in sent]
    print("\n---- Result after encoding")
    print("text: {}".format(text[0:2]))
    text = pad_sequences(text, 0, max_len_seq)
    print("\n---- Result after padding")
    print("text_train: {}".format(text[0:2]))
    text_test, label_test = create_in_out(text) ## Create input output for the model
    print("\n---- Result after creating x and y")
    print("text_train: {}".format(text_test[0:2]))
    print("label_train: {}".format(label_test[0:2]))

    return text_test, label_test

def processing(raw_text, max_len_seq, eof_flag, glove_flag):
    text, words = tokenize(raw_text, eof_flag=eof_flag) ## Tokenize
    print("\n---- Result after tokenization")
    print("Length words: {}".format(len(words)))
    print("words: {}".format(words))
    print("text: {}".format(text[0:2]))
    text = split_sequences(text, max_len_seq) ## Split in sequences
    print("\n---- Result after reorganizing by sequences")
    print("text: {}".format(text[0:2]))
    print("len(text): {}".format(len(text)))
    print("max_len_seq: {}".format(max_len_seq))
    if glove_flag:
        print('ok')
        text, word2idx, idx2word, words = encode(text, words, limit_appear=False, eof_flag=eof_flag) ## Encode
        weights_matrix, glove = encode_glove(words, eof_flag=eof_flag) #create weight matrix
        encod = word2idx
        unencod = idx2word
        vocab_size = len(weights_matrix)
    else:
        text, word2idx, idx2word, words = encode(text, words, eof_flag=eof_flag) ## Encode
        encod = word2idx
        unencod = idx2word
        weights_matrix = []
        vocab_size = len(encod)
    print("\n---- Result after encoding")
    print("text_train: {}".format(text[0:2]))
    text = pad_sequences(text, 0, max_len_seq)
    print("\n---- Result after padding")
    print("text_train: {}".format(text[0:2]))
    text_train, label_train = create_in_out(text) ## Create input output for the model
    print("\n---- Result after creating x and y")
    print("text_train: {}".format(text_train[0:2]))
    print("label_train: {}".format(label_train[0:2]))
    print("vocab size: {}".format(vocab_size))
    return text_train, label_train, vocab_size, encod, unencod, weights_matrix, words

# %%
class WordLSTM(nn.Module):
    def __init__(self, n_hidden=256, n_layers=4, drop_prob=0.3, lr=0.001, mode='', weights_matrix=[]):
        super().__init__()
        self.drop_prob = drop_prob
        self.n_layers = n_layers
        self.n_hidden = n_hidden
        self.lr = lr
        if mode=='glove':
            num_embeddings=weights_matrix.shape[0]
            embedding_dim=weights_matrix.shape[1]
            ## init lookup table (int index --> vector embedding)
            self.emb_layer = nn.Embedding(num_embeddings, embedding_dim)
            ## load the content into the lookup table
            self.emb_layer.weight = nn.Parameter(torch.tensor(weights_matrix,dtype=torch.float32))
            #self.emb_layer.load_state_dict({'weight': weights_matrix})
            self.emb_layer.weight.requires_grad = False
        else:
            embedding_dim = 200
            self.emb_layer = nn.Embedding(vocab_size, embedding_dim)
        print('vocab_size ',vocab_size)
        self.lstm = nn.LSTM(embedding_dim, n_hidden, n_layers, dropout=drop_prob, batch_first=True)
        self.dropout = nn.Dropout(drop_prob)
        self.fc = nn.Linear(n_hidden, vocab_size)  # output: 1 out for each word in the vocab

    def forward(self, x, hidden):
        ## pass input through embedding 
        embedded = self.emb_layer(x)#torch.LongTensor(x)) 
        '''embedding_vec=embedding(torch.LongTensor(text_token))
        print(embedding)
        print(embedding_vec.shape)'''
        lstm_output, hidden = self.lstm(embedded, hidden) ## Get the outputs and the new hidden state from the lstm
        out = self.dropout(lstm_output) ## pass through a dropout layer
        out = out.reshape(-1, self.n_hidden) 
        out = self.fc(out)
        return out, hidden # return the final output and the hidden state
    def init_hidden(self, batch_size):
        ''' initializes hidden state '''
        # Create two new tensors with sizes n_layers x batch_size x n_hidden,
        # initialized to zero, for hidden state and cell state of LSTM
        weight = next(self.parameters()).data
        if (torch.cuda.is_available()):
          hidden = (weight.new(self.n_layers, batch_size, self.n_hidden).zero_().cuda(),
                    weight.new(self.n_layers, batch_size, self.n_hidden).zero_().cuda())
        else:
          hidden = (weight.new(self.n_layers, batch_size, self.n_hidden).zero_(),
                    weight.new(self.n_layers, batch_size, self.n_hidden).zero_())
        return hidden

# Build batches
def get_batches(arr_x, arr_y, batch_size):
    prv = 0
    for n in range(batch_size, arr_x.shape[0], batch_size):
      x = arr_x[prv:n,:]
      y = arr_y[prv:n,:]
      prv = n
      yield x, y

# predict next token
def predict(net, tkn, encod, unencod, h=None):      
    # tensor inputs
    x = np.array([[encod[tkn]]])
    inputs = torch.from_numpy(x)
    # push to GPU
    inputs = inputs.cuda()
    # detach hidden state from history
    h = tuple([each.data for each in h])
    # get the output of the model
    out, h = net(inputs, h)
    # get the token probabilities
    p = F.softmax(out, dim=1).data
    p = p.cpu()
    p = p.numpy()
    p = p.reshape(p.shape[1],)
    # get indices of top 3 values
    top_n_idx = p.argsort()[-3:][::-1]
    # randomly select one of the three indices
    sampled_token_index = top_n_idx[random.sample([0,1,2],1)[0]]
    # return the encoded value of the predicted char and the hidden state
    return unencod[sampled_token_index], h
# function to generate text
def sample(net, size, encod, unencod, prime='<s>'):  
    # push to GPU
    net.cuda()
    net.eval()
    # batch size is 1
    h = net.init_hidden(1)
    toks = prime.split()
    # predict next token
    for t in prime.split():
      token, h = predict(net, t, encod, unencod, h)
    toks.append(token)
    # predict subsequent tokens
    for i in range(size-1):
        token, h = predict(net, toks[-1], encod, unencod, h)
        toks.append(token)
        if token == '</s>':
            break
    return ' '.join(toks)

def train(net, x, y, epochs=10, batch_size=32, lr=0.001, clip=1, print_every=32):
    # optimizer
    opt = torch.optim.Adam(net.parameters(), lr=lr)
    # loss
    criterion = nn.CrossEntropyLoss()
    # push model to GPU
    net.cuda()
    net.train()
    for e in range(0, epochs):
        counter = 0
        # initialize hidden state
        h = net.init_hidden(batch_size)
        for x, y in get_batches(text_train, label_train, batch_size):
            counter+= 1
            # convert numpy arrays to PyTorch arrays
            inputs, targets = torch.from_numpy(x), torch.from_numpy(y)
            # push tensors to GPU
            #inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = inputs.cuda().long(), targets.cuda().long()
            # detach hidden states
            h = tuple([each.data for each in h])
            # zero accumulated gradients
            net.zero_grad()
            # get the output from the model
            output, h = net(inputs, h)
            # calculate the loss and perform backprop
            loss = criterion(output, targets.view(-1))
            # back-propagate error
            loss.backward()
            # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
            nn.utils.clip_grad_norm_(net.parameters(), clip)
            # update weigths
            opt.step()            
            #if counter % print_every == 0:
              #print("Epoch: {}/{}...".format(e+1, epochs),"Step: {}...".format(counter))
        print("Epoch: {}/{}...".format(e+1, epochs), "Loss: {:.6f}...".format(loss.item()))

import math
criterion = nn.CrossEntropyLoss() 
def getloss(net, tkn, tkn2, h=None):      
  # tensor inputs
  with torch.no_grad():
    x = np.array([[encod[tkn]]])
    y = np.array([[encod[tkn2]]])
    inputs = torch.from_numpy(x)
    target = torch.from_numpy(y)
    # push to GPU
    inputs = inputs.cuda()
    target = target.cuda()
    # detach hidden state from history
    h = tuple([each.data for each in h])
    # get the output of the model
    out, h = net(inputs, h)
    criterion = nn.CrossEntropyLoss() 
    test_loss = criterion(out, target.view(-1))
  return test_loss, h
def sent_perp(sent, net):
    l = sent.split(' ')
    log_prob = 0
    h = net.init_hidden(1)	
    #for word in l[0:-1]:
    for i in range(len(l)-1):
      word = l[i]
      word2 = l[i+1]
      if word not in words:
        word = '_UNK'
      if word2 not in words:
        word2 = '_UNK'
      test_loss, h = getloss(net, word, word2, h)
      log_prob = log_prob + test_loss
    return log_prob 

def test(net, text_test):
    with open(PATH + text_test) as f:#'test_1.txt'
      test_data = f.read()

    test_data = test_data.split('\n')
    N = 0
    P = 0
    for sent in test_data:
      N = N + len(sent.split(' '))
      P = P + sent_perp(sent, net)
    temp = P/N
    perplexity = torch.exp(temp)
    return temp, perplexity

# %%
## LOAD DATA
with open(PATH+'prideAndPrejudice.txt') as f:
    raw_text = f.readlines()
with open(PATH+'test_1.txt') as f:
    raw_test_1 = f.readlines()
with open(PATH+'test_2.txt') as f:
    raw_test_2 = f.readlines()
with open(PATH+'tweet.txt') as f:
    raw_tweet = f.readlines()
#raw_text = [re.sub("[^a-zA-Z\.\,\!\?\' ]", "", i) for i in raw_text]
#raw_tweet = [re.sub("[^a-zA-Z\.\,\!\?\'\<\/\> ]", "", i) for i in raw_tweet]

#text = text[0:2]
print("\n---- Preliminary text analysis")
print("Length text: {}".format(len(raw_text)))
print("Length test1: {}".format(len(raw_test_1)))
print("Length test2: {}".format(len(raw_test_2)))
print("Length raw_tweet: {}".format(len(raw_tweet)))
# Out:
# ---- Preliminary text analysis
# Length text: 2063
# Length test1: 924
# Length test2: 1000
# Length raw_tweet: 6000

# %%
## Question 1
max_len_seq = 5
text_train, label_train, vocab_size, encod, unencod, _, words= processing(raw_text.copy(), max_len_seq, True, False) #text_train, label_train, encod, weights_matrix
# Out:
# ---- Result after tokenization
# Length words: 6553
# words: Counter({',': 9129, '.': 5047, 'the': 4331, 'to': 4137, 'of': 3608, 'and': 3577, 'her': 2203, 'i': 2064, 'a': 1947, 'in': 1865, 'was': 1844, '``': 1785, "''": 1747, 'she': 1695, 'that': 1540, ';': 1538, 'it': 1535, 'not': 1533, 'you': 1326, 'he': 1324, 'his': 1258, 'be': 1240, 'as': 1179, 'had': 1172, 'for': 1058, 'with': 1051, 'but': 1002, 'is': 860, 'have': 840, 'at': 788, 'mr.': 764, 'him': 753, 'on': 716, 'my': 703, "'s": 648, 'by': 635, 'elizabeth': 635, 'all': 621, 'they': 597, 'so': 589, 'were': 563, 'which': 538, 'could': 525, 'been': 515, '!': 499, 'from': 493, 'no': 490, 'very': 485, 'what': 478, 'would': 468, '?': 462, 'this': 441, 'their': 441, 'your': 440, 'me': 429, 'them': 429, 'darcy': 417, 'will': 404, 'said': 401, '--': 394, 'such': 386, 'when': 373, 'an': 354, 'if': 350, 'there': 348, 'do': 347, 'mrs.': 341, 'are': 338, 'much': 326, 'bennet': 323, 'more': 323, 'can': 322, 'am': 316, 'must': 305, 'bingley': 305, 'or': 300, 'jane': 291, 'who': 284, 'miss': 283, 'than': 282, 'any': 268, 'one': 267, 'did': 266, 'we': 247, 'should': 245, 'know': 236, 'how': 231, 'before': 227, 'herself': 227, 'though': 226, 'has': 221, 'never': 218, 'soon': 216, 'sister': 216, 'only': 215, 'well': 214, 'think': 211, 'other': 210, 'some': 207, 'now': 204, 'time': 200, 'might': 200, 'after': 199, 'every': 198, 'wickham': 194, 'may': 191, 'lady': 190, 'little': 188, 'most': 187, 'good': 183, 'own': 182, 'collins': 180, 'nothing': 177, 'again': 177, 'then': 174, 'being': 174, 'without': 171, 'lydia': 170, 'make': 165, 'shall': 161, 'say': 160, 'dear': 158, 'family': 151, 'man': 150, 'see': 149, 'first': 145, 'into': 142, 'great': 141, 'too': 141, 'father': 135, 'however': 134, 'mother': 134, 'day': 133, ':': 133, 'two': 132, 'out': 132, 'young': 130, 'ever': 130, 'himself': 127, 'made': 126, 'catherine': 126, 'give': 123, 'about': 122, 'hope': 121, 'us': 121, 'last': 119, 'always': 119, 'many': 119, 'away': 117, 'letter': 115, 'long': 114, 'friend': 112, 'room': 112, 'thought': 112, 'up': 111, 'way': 108, 'enough': 106, 'house': 106, 'its': 105, 'go': 104, 'replied': 103, 'saw': 103, 'sure': 102, 'manner': 99, 'felt': 99, 'lizzy': 97, 'wish': 97, 'gardiner': 97, 'quite': 96, 'indeed': 95, 'having': 95, 'oh': 94, 'come': 93, 'till': 93, 'myself': 93, 'better': 92, 'pleasure': 92, 'done': 92, 'cried': 91, 'love': 91, 'came': 90, 'over': 89, 'often': 89, 'where': 89, 'really': 88, 'longbourn': 88, 'believe': 87, 'feelings': 86, 'daughter': 85, 'charlotte': 85, 'heard': 84, 'subject': 84, 'whom': 84, 'aunt': 84, 'does': 83, 'happy': 83, 'even': 82, 'take': 80, 'anything': 80, 'morning': 79, 'whole': 79, 'sir': 78, 'like': 77, 'less': 77, 'perhaps': 76, 'sisters': 76, 'upon': 76, 'seen': 76, 'let': 75, 'therefore': 75, 'while': 75, 'brother': 75, 'yes': 75, 'our': 74, 'evening': 74, 'ladies': 74, 'looked': 74, 'netherfield': 73, 'just': 73, 'down': 73, 'place': 73, 'nor': 73, 'yet': 73, 'still': 72, 'certainly': 72, 'happiness': 72, 'tell': 71, 'next': 71, 'few': 71, 'something': 71, 'kitty': 71, 'hear': 71, 'added': 71, 'both': 71, 'lucas': 70, 'moment': 70, 'told': 69, 'these': 69, 'same': 69, 'opinion': 68, 'attention': 68, 'uncle': 68, 'here': 67, 'towards': 67, 'present': 67, 'went': 67, 'speak': 66, 'world': 66, 'found': 66, 'seemed': 66, 'home': 66, 'marriage': 66, 'colonel': 66, 'answer': 65, 'least': 65, 'left': 65, 'character': 64, 'town': 64, 'together': 64, 'between': 63, 'each': 63, 'gone': 62, 'off': 62, 'because': 62, 'married': 61, 'conversation': 61, 'passed': 61, 'leave': 61, 'kind': 61, 'received': 61, 'immediately': 60, 'part': 60, 'seeing': 60, 'coming': 60, 'woman': 59, 'since': 59, 'those': 59, 'began': 59, 'either': 59, 'whose': 59, 'almost': 59, 'find': 58, 'affection': 58, 'far': 58, 'known': 57, 'party': 57, 'mind': 57, 'knew': 57, 'once': 57, 'going': 57, 'means': 57, 'look': 57, 'meryton': 57, 'three': 57, 'life': 56, 'another': 56, 'possible': 56, 'friends': 55, 'certain': 55, 'london': 55, 'rather': 5 ...
# text: [['<s>', 'it', 'is', 'a', 'truth', 'universally', 'acknowledged', ',', 'that', 'a', 'single', 'man', 'in', 'possession', 'of', 'a', 'good', 'fortune', ',', 'must', 'be', 'in', 'want', 'of', 'a', 'wife', '.', '</s>'], ['<s>', 'however', 'little', 'known', 'the', 'feelings', 'or', 'views', 'of', 'such', 'a', 'man', 'may', 'be', 'on', 'his', 'first', 'entering', 'a', 'neighbourhood', ',', 'this', 'truth', 'is', 'so', 'well', 'fixed', 'in', 'the', 'minds', 'of', 'the', 'surrounding', 'families', ',', 'that', 'he', 'is', 'considered', 'the', 'rightful', 'property', 'of', 'some', 'one', 'or', 'other', 'of', 'their', 'daughters', '.', '</s>']]
#
# ---- Result after reorganizing by sequences
# text: [['<s>', 'it', 'is', 'a', 'truth', 'universally'], ['it', 'is', 'a', 'truth', 'universally', 'acknowledged']]
# len(text): 137164
# max_len_seq: 5
#
# ---- Result after encoding
# text_train: [[2, 20, 31, 12, 539, 2433], [20, 31, 12, 539, 2433, 696]]
#
# ---- Result after padding
# text_train: [[2, 20, 31, 12, 539, 2433], [20, 31, 12, 539, 2433, 696]]
#
# ---- Result after creating x and y
# text_train: [[   2   20   31   12  539]
#  [  20   31   12  539 2433]]
# label_train: [[  20   31   12  539 2433]
#  [  31   12  539 2433  696]]
# vocab size: 3970

# %%
## Instantiate the model
net = WordLSTM().cuda() # push the model to GPU (avoid it if you are not using the GPU)
print(net)
train(net, text_train, label_train, batch_size = 32, epochs=20, print_every=4000) ## Train the model
torch.save(net, PATH+'model_save_5.pt') ## Save
# Out:
# vocab_size  3970
# WordLSTM(
#   (emb_layer): Embedding(3970, 200)
#   (lstm): LSTM(200, 256, num_layers=4, batch_first=True, dropout=0.3)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=256, out_features=3970, bias=True)
# )
# Epoch: 1/20... Loss: 5.469995...
# Epoch: 2/20... Loss: 5.164315...
# Epoch: 3/20... Loss: 4.776531...
# Epoch: 4/20... Loss: 4.660214...
# Epoch: 5/20... Loss: 4.441027...
# Epoch: 6/20... Loss: 4.295032...
# Epoch: 7/20... Loss: 4.240712...
# Epoch: 8/20... Loss: 4.240494...
# Epoch: 9/20... Loss: 4.234482...
# Epoch: 10/20... Loss: 3.978645...
# Epoch: 11/20... Loss: 3.991458...
# Epoch: 12/20... Loss: 4.021789...
# Epoch: 13/20... Loss: 4.052073...
# Epoch: 14/20... Loss: 3.805040...
# Epoch: 15/20... Loss: 3.830575...
# Epoch: 16/20... Loss: 3.940037...
# Epoch: 17/20... Loss: 3.819937...
# Epoch: 18/20... Loss: 3.743596...
# Epoch: 19/20... Loss: 3.682145...
# Epoch: 20/20... Loss: 3.835780...

# %%
net = torch.load(PATH+'model_save_5.pt')
net.eval()
## Generate words 
for i in range(10):
    print("Example {} generated: ".format(i))
    print(sample(net, 500, encod, unencod, prime = "<s>"))
# Out:
# Example 0 generated:
# <s> elizabeth , who came on stairs with the familiarity and _UNK , and _UNK of her family ; she was necessarily drawn from her father 's instructions ; for when she was in the room . he bore him , to the _UNK and _UNK , _UNK of her sisters ' , she was in a _UNK , and the others , she had a little less _UNK than the subject of the match , she was _UNK in her marriage . she could not be vulgar . '' and she could have nothing to be sure . he was the _UNK of his wife and elizabeth had been prevailed to town . he was the _UNK of the persons who was a very large woman . the evening were _UNK in her own room , she had the _UNK _UNK of their being not help her , and the evening were in her way to be _UNK . she was not to speak to jane , and the evening were spent from the pursuit of courtship much of her earnest . she was the _UNK , and she had the highest gratitude to the world ; for she had a little _UNK from her husband , she was still acquainted in the room ; she had a little longer in a _UNK of the room , she was a _UNK , and the others was sitting on the _UNK . </s>
# Example 1 generated:
# <s> elizabeth was not alarming , but it would not have happened . she had not the _UNK , and _UNK , and _UNK . elizabeth had never been in the room , he could never help the rest and _UNK . her mother 's sake ; but she could , she had been prevailed to her , was not the last time to be _UNK by a _UNK . the _UNK , she could never listen with the _UNK , was _UNK , she could _UNK of his own party , she could have a great humour to the world . </s>
# Example 2 generated:
# <s> the _UNK was to see you . i shall have a great _UNK , you must be _UNK by the match . you are not deceived . '' cried jane . </s>
# Example 3 generated:
# <s> elizabeth had been so tiresome as she was not to make him a word , was not to be so much to be reasonable , but it would be in her way . she was a _UNK of visiting on the room , and _UNK of their affection . </s>
# Example 4 generated:
# <s> elizabeth was still _UNK by his marriage ; for , as soon , was a great deal in town , she had never seen her . </s>
# Example 5 generated:
# <s> `` you have not been so reasonable , and i shall not think of it ; but i am sure i should be so happy . you have been so tiresome , and , perhaps of your going to be impossible . you must not have been a good joke to her , she had the same time to be _UNK , she was not to give her the evening in the world . she could never listen to the _UNK , was _UNK , _UNK woman , and she had been _UNK , but she had been in her own room , and the morrow of the evening who was the very great direction . she was a _UNK , _UNK , _UNK woman ; and she could _UNK the satisfaction which she was indebted for his _UNK , to sit at the end of his wife 's , was a great _UNK to the window , and the comfort which she was to be _UNK to the lakes , he was _UNK by the occasion ; but as to the rest , she had been _UNK , she had never yet _UNK to the _UNK , she had been in the room , and the evening passed away ; but , as to make her consent to her father and aunt were to be prevailed at the end to her father 's example ; but as the evening was prevailed to the pursuit which her husband had not yet _UNK to her father , who was a very large , _UNK woman . she had the highest opinion of her sisters . he bore it ; and she was necessarily evident , but it had not yet _UNK of her temper , was the evening before he could not listen , she was not deceived , but was still to see him , he was in a humour to _UNK , and she could never be _UNK , she could hardly listen to his friend , she dropt all the evening was _UNK and invariably different , _UNK , she dropt all her resentment ; but she had a _UNK _UNK of their being not in her power to obtain her _UNK . she had never inspired in love in a neighbouring way , and her _UNK , and _UNK of her family , and _UNK , she was in the room . her , and she was sitting from a _UNK , and _UNK , she was too _UNK . the two daughters spent in the world , was not to be _UNK . the _UNK of her sisters . he had been so happy , and she could not listen , he was _UNK in a way , which , as she was in the habit of _UNK , and _UNK of her family . he had not a _UNK , _UNK of the _UNK . she looked down , and the morrow was not the
# Example 6 generated:
# <s> the ladies was not of his _UNK , and the _UNK . she was not so tiresome as they entered the restoration to _UNK her , she dropt the _UNK , and _UNK of the rest , and the _UNK . she could not help the room . she had been so indignant as the _UNK , she could have been in town , and her husband 's sake . </s>
# Example 7 generated:
# <s> elizabeth was still _UNK , and talked , which was to be _UNK , she was necessarily drawn from a _UNK , and the _UNK , was the case ; he could be so happy . the _UNK was _UNK , and the comfort of giving him the match , and _UNK , she had a letter in her father 's example ; for as to her own feelings ; but she had a _UNK of her daughters . he had been so much to be done , but , however ; for elizabeth was still relieved with a letter , she could not have been in a humour which he had ever intended for her , as she was in the world , was the evening before they entered the world ; but , when they were in the evening , she dropt all her resentment , she could not listen . she had not been so much to her , which was the _UNK of her family . she had the highest gratitude in her way to the lakes ; for she had a _UNK of her _UNK and _UNK . the _UNK of her family , she dropt the room . he bore her to be _UNK by the match ; but as she had been so much embarrassed in the world . he bore her . she could have a syllable _UNK , and the morrow , _UNK , _UNK woman ; but , as they had the advantage , which , in spite , she was not able for his _UNK , she had the _UNK and _UNK . her father , who followed her with an end for the _UNK and anxious , and elizabeth 's example , was the evening in her way in her own room ; she was not in a few minutes , who was a large , _UNK , wild man ; but it is a good girl , which i was in the room . i was so _UNK . i was so _UNK . '' </s>
# Example 8 generated:
# <s> `` oh ! my dear lizzy , i was sure you will not be so happy . you will not make her , if he was not to be _UNK to the _UNK . </s>
# Example 9 generated:
# <s> `` i am not so shy of your own . i am not so unwilling to make her happy ; for , to be decent the room , he assisted them to be prevailed to her father and aunt , who followed him at pemberley , and she could not listen , and her manners at pemberley . he had been so much to her own , she dropt her , she was still _UNK , but , however ; but she was in her way , she was still sensible to her , she had been prevailed from her , she could hardly listen to her , she could never have the earliest information which her marriage would have been so _UNK to her , or _UNK , she could never help writing the _UNK . she could not be prevailed on , to make her a word . she was the happiest , _UNK woman , she had been so much engaged in the _UNK , and _UNK to the _UNK , was not so _UNK as they were indebted to her husband , who followed him , she could , and she saw that she was a great humour , and her husband , though she was going on , was not the same , _UNK of the room ; she could have a great _UNK to her , was the _UNK , was delighted with her husband 's letter . he was not so much as to be _UNK . </s>

# %%
## Question 2
max_len_seq = 0
net = torch.load(PATH+'model_save_5.pt')
net.eval()
test_loss, perplexity = test(net, 'test_1.txt')
print('test loss {:5.2f} | test perplexity {:8.2f}'.format(test_loss.item(), perplexity))
# Out:
# test loss  5.04 | test perplexity   154.58

# %%
## Question 3
max_len_seq = 25
text_train, label_train, vocab_size, encod, unencod, _, words = processing(raw_text.copy(), max_len_seq, True, False)

# %%
net = WordLSTM().cuda() # push the model to GPU (avoid it if you are not using the GPU)
print(net)
train(net, text_train, label_train, batch_size = 32, epochs=20, print_every=4000) ## Train the model
torch.save(net, PATH+'model_save_25.pt') ## Save
# Out:
# vocab_size  3970
# WordLSTM(
#   (emb_layer): Embedding(3970, 200)
#   (lstm): LSTM(200, 256, num_layers=4, batch_first=True, dropout=0.3)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=256, out_features=3970, bias=True)
# )
# Epoch: 1/20... Loss: 5.165695...
# Epoch: 2/20... Loss: 4.619696...
# Epoch: 3/20... Loss: 4.176872...
# Epoch: 4/20... Loss: 4.002927...
# Epoch: 5/20... Loss: 3.786731...
# Epoch: 6/20... Loss: 3.692864...
# Epoch: 7/20... Loss: 3.560080...
# Epoch: 8/20... Loss: 3.469120...
# Epoch: 9/20... Loss: 3.320129...
# Epoch: 10/20... Loss: 3.286344...
# Epoch: 11/20... Loss: 3.186706...
# Epoch: 12/20... Loss: 3.088893...
# Epoch: 13/20... Loss: 3.017620...
# Epoch: 14/20... Loss: 2.962198...
# Epoch: 15/20... Loss: 2.852405...
# Epoch: 16/20... Loss: 2.858321...
# Epoch: 17/20... Loss: 2.886101...
# Epoch: 18/20... Loss: 2.827587...
# Epoch: 19/20... Loss: 2.734997...
# Epoch: 20/20... Loss: 2.692246...

# %%
net = torch.load(PATH+'model_save_25.pt')
net.eval()
## Generate words 
for i in range(10):
    print("Example {} generated: ".format(i))
    print(sample(net, 500, encod, unencod, prime = "<s>"))
# Out:
# Example 0 generated:
# <s> but i have no reason , but not so many ! -- i am happier even . you ought to have gone on . but i have not observed , by your imagination , you know , that he had always courage for your kindness for the kindness which his affection to the lakes ; but as he was the last , she would be always _UNK by his affection to the efforts and spending all the country ; when he wished for the match . she had always fallen on his affection with _his_ promise to see with her husband . he bore the _UNK , _UNK _UNK . he _UNK , and said that they was going in her private room ; she had always seen it . the former wish of his life , however , was extreme . mrs. gardiner had never seen him in a chaise . she was always of his good temper . she could conquer the place . the ladies were post . she had always seen her joy . she was in her power for an assistance which her estimation was great than a _UNK , _UNK woman . he had been a _UNK in the north which must be _UNK in her marriage , she had still made her own _UNK in the north . elizabeth had heard only to speak for the _UNK . the ladies had crowded in the country ; or of his _UNK and talents ; but , when they were all drawn with her , she had been rendered so early as as to suppose how bingley , she had been able for a chaise , that her husband was still in the habit of spending an interval for gaiety ; but the others was a great _UNK in the room , which was the case , and elizabeth silently consented ; but she checked with a large time in a large , allowed on an hour , _UNK in general circulation . the _UNK of the peace of a family , and _UNK with all his _UNK and talents . she was the most disagreeable , _UNK woman , less irritable , less irritable , _UNK , less _UNK . the time in a humour to trifle on her brother , and talked of all his _UNK . elizabeth was pleased that he should not have a great source to love for the place , but the morrow passed off much better than she expected . she had never yet been a _UNK , or _her_ _UNK . jane was not in so much awe and _UNK . her mother 's happiness was still so early gratified , and the _UNK of her mother and uncles in quest of her mother , less _UNK , less ignorant . mrs. gardiner had been formed in a neighbouring county to derbyshire ; and , though she had always been so unwilling for as much as they
# Example 1 generated:
# <s> but , however , you have certainly known the trouble of a man , and the _UNK and remarkably _UNK , and i am not so unwilling to make it more elegant . it will be so much as i ought . you must have hated you a word . i have been a great comfort with him in such happy manners ! what do you come down for the lakes , but i am convinced what i am to tell him of the world . '' </s>
# Example 2 generated:
# <s> i am not afraid of being the case ; and though you were sick , you ought , you know ; and , if you have been always so _UNK to do , i hope you would be very reasonable , if we have been _UNK with her twice ; but if you are all drawn to town . i have no money . your attachment , you thoroughly despised her life . you have been mistaken . mr. bennet is very insufficient and despised you are gone in town . but in the bingleys , perhaps he was very good women , though not _UNK to the honour and nonsense which she could derive from the season and _UNK of his wife , that the accomplishment of his affection for her was sunk on the conviction that she was sitting with mrs. hurst , and her resolution and easy , were very great . it could be in the course which his marriage was still _UNK . she had not seen them in a humour to make them by her own fortune . she had been so happy as to make him so much , and the woods with her father , who was obliged that he had been prevailed at the door , but the first two dances , she was able that her heart were affected by the match . she was not of the good humour which her _UNK were _UNK , she assisted him nervous ; and , removed from her own , he could not spare herself , though the morrow was much to make the place with elizabeth . her brother 's _UNK , she was so much affected with the match , that she had not mortified her so much , and _UNK _UNK , _UNK of talking to him , and the evening in a neighbouring direction to _UNK the offence . the _UNK letter and agreeable , less irritable . she had never been so _UNK as to be _UNK in her marriage , she had still inspired with her twice , was in the middle , _UNK _UNK with the match ; and she was not so happy engaged as to be so fine as in her husband 's , she had always yet been evident by his own , nor expressed the _UNK . elizabeth had never seen him so far in the bingleys , and elizabeth silently _UNK with the subject which almost existed , and her husband , in the habit which elizabeth had formed , relating her absolute certainty that the subject , she was in a humour for economy to her mother , less _UNK in his marriage ; nor did you mean called at all as soon as he was , and _UNK , and _UNK . elizabeth _UNK so well applied . i have no longer bear you all . i have not the grief of accounting for the frequent _UNK of
# Example 3 generated:
# <s> but , however , you know how to be so happy to be so reasonable as as to admit it . i have saved you a year . but now , lizzy ! i can not think that it was very well , to make you love me ; and i am not afraid of being all speaking . but tell him what you ought to have been a year , i am afraid you did , but he was going in her own room . i am sure it would not be more than a woman licence . you must learn so _UNK a great deal of _UNK , if he _UNK , if you had been married , you know . you are not so _UNK as i can . you are always moving by your nerves ; and though i have given your disposition , i shall not comprehend to write ; for , though he was more than i ought , for a _UNK , _UNK young man , _UNK girl , and less _UNK ; and , in all likelihood . i have been so _UNK as you can . you must go on a _UNK , '' she replied ; and she was not of the good importance , which she was not so happy in his marriage . she was a little _UNK on his _UNK ; but , as she was prevailed with him at once in the room . </s>
# Example 4 generated:
# <s> `` what do i think of you ? what is your _UNK flow . i have saved you the lakes , and repeat a few lines with the young man who is charming . i have no idea of it . i am not of a _UNK . i have not spoken you , for i have no means married ; but , though he was the only suspicion , she could have a _UNK scheme . i am happier even ! i have saved him so well , to be very anxious to write to you , in all your _UNK and _UNK over her husband 's , was not so great different _UNK ; and she checked herself . she bore him in every time , and unable to _UNK more or ignorant which her affection would allow , and was _UNK in the course which elizabeth made an assistance in the match , when she complimented them on her husband , though the door which was to the work and economy of his own , and talked , of a _UNK addition to her husband and her mother 's _UNK ; she was not able that she was generally evident that she was prevailed at her mother 's _UNK , and the substance of her sisters , was still in the direction which bingley should _UNK a little longer . the _UNK _UNK which was to become _UNK , and the evening had soon formed , relating the professed reflection which led her own change and mortification . elizabeth was delighted ; but she was perfectly ashamed for their kindness with bingley . she had not inspired acquainted in her own private assurances to mr. darcy , to the wish of her _UNK . the gentlemen had been formed in quest of her family . he bore every assistance in her marriage . elizabeth , though he had seen her sister , when he ceased of her nephew 's indifference ; but though they had the pleasure and management , walking in a _UNK manner . elizabeth was obliged to her mother , whose manners gave way , either on his own . the party was sent with a _UNK _UNK which she could not determine , and she could not listen with him at all . the gentlemen were sent by a _UNK of _UNK ; but she looked forward for the subject of the sisters . she had always learnt for the place ; but she could not help _UNK her with a _UNK way . the arrival of a person must be in town , she could not be prevailed from her husband . her husband was not in town ; but though she had the pleasure which his affection was so unlike as to be always acquainted by the pursuit of courtship by her own private fortune ; or to speak which she could not be _UNK by his wife ; but though
# Example 5 generated:
# <s> `` oh , my sweetest aunt , i should never be vulgar ; and in spite , of all the sake which her sister had always received them at once . he bore that he had always seen it . he was in the power which prevailed to _UNK with them ; and in the _UNK , she retained all his _UNK . the gentlemen declared the tide of her mother , whose own _UNK _UNK with the familiarity and courtship which she was indebted and _UNK . elizabeth 's manners was _UNK by the match . elizabeth was delighted with the pursuit which the subject was so fine to _UNK . the suspicions was so recent for gaiety . she was always of her mother 's opposition , she dropt the offence , she bought the _UNK . she had not inspired enough for half the _UNK of his _UNK . he had always seen it in his _UNK ; and she was in her way with the season of spending much more in the _UNK of her sisters . he bore it , however ; for she had been a most welcome young men , _UNK to the rest and promise which she had always suspected to make him _UNK , but in a part to her husband 's indifference and grandeur , though not in general _UNK to her own fortune , she retained her own time of being _UNK by the north which announced the direction of her nephew had always mortified them for such a _UNK , that her brother had been obliged that he was not of her hopes , she was not able to keep the pursuit and mortification , less irritable . elizabeth had not hoped to think better of him . she was not of the good importance , she was so unequal for her husband 's _UNK . she was still drawn by her two elder girls ; and when they changed speaking to mrs. bennet 's _UNK . elizabeth was obliged for her husband . elizabeth had never yet been so tiresome a great deal to say of bingley . she was not so happy engaged as almost in a manner as almost a _UNK , _UNK _UNK . she had been a most welcome creature that her estimation and temper , though she was so removed from the north of courtship off , and the morrow were not _UNK by his affection for her ; and , though the visitor was _UNK from the match ; but elizabeth , who rejoicing in the north of the _UNK of visiting on his _UNK and frankness to a good _UNK . the gentlemen were _UNK ; and she was necessarily more quiet . the _UNK letter was _UNK , she had been unwilling for his own . it was the _UNK , _UNK , satisfactory . the party were _UNK , and the _UNK of the world . elizabeth ,
# Example 6 generated:
# <s> i have not a letter for her , but i can not be so happy in your life . i was not in a different humour ; and in spite of the world that i might not be so silly in your life , that i was happier in awe and _UNK ; and though you were not a great girl , i am afraid of pleasure . you are all to be a great girl to make it quite a man in the _UNK . the _UNK letter to her sister was still a little desirable in town , and the chosen desire of his warmest desire in his life , that her estimation of her sister 's happiness was extreme , she had still inspired in the room ; for when she was violently set from her affection for the match , elizabeth was still gratified by her husband . the gentlemen had given her two daughters quite evident , she had always felt , that the _UNK was _UNK , she was so much disposed of it ; though she could not help _UNK her . the _UNK of the country was paid with the _UNK , and of his good humour . her mother had yet been in town . she could not be prevailed on to wait with her , but the evening were _UNK from his affection to her husband , when they were all set down , however , _UNK of all the contents which she had yet been able to keep her abhorrence of the _UNK ; and though the restoration and peace of giving them a few minutes had always made him a little _UNK on the world , was unsettled on it , when they were always speaking . she was a _UNK _UNK by his _UNK . the girls were _UNK . the gentlemen were indebted for their society . the _UNK _UNK which had been of a man to her mother , who could be guessed on his good qualities ; but , consequently to make her more handsomer , he turned to the room . the ladies was indebted which had been always _UNK with her . he was a great comfort to him , when she was able for the brightest _UNK of her sisters ' suspense . her heart and falsehood was _UNK by the north , which was very little mortified for a neighbouring _UNK . it was not a little longer . elizabeth 's society had given him an hour , was still _UNK to her mother and aunt , who could not be vulgar , she could listen . she bore him in a _UNK manner in her face ; but when the _UNK were _UNK in his own room , he had been able to overcome him from her mother , was unsettled to her two daughters in the north , and elizabeth 's _UNK . elizabeth was obliged of the
# Example 7 generated:
# <s> but , however ! how heartily i am sure , and not , indeed . i am sure i am happier enough to keep it . my father and aunt , '' replied elizabeth . she was a most _UNK , good woman . but , however ! you must be so rich ! i was sure i sha your disposition to be _UNK by her affection . i have no more , to assure me of your love , if you have always been married . you must not have the grief of removing all her mother 's opposition ; and though we have widely _UNK to longbourn ; and , though i hope you would not be prevailed from him , if he was come with us ; for , in course of the rest . it is not so much to see them in a _UNK _UNK . i was not so silly from either as i am , and not _UNK us from her nephew , and i have not been so mean as to overcome you . i have not been so silly to _UNK you . i was not in a good humour to wait to you all , i was so unlike all from your children ! what is the case , you ought for the foundation . '' she cried . but , though he had always _UNK it . i have saved you you all . i have saved her so long as long in a _UNK way . but i have not a great objection to your own . you have always _UNK you so much , for i ought not of being so silly in the world . i shall not go on , and the chosen partner and good heart . i am sure i was so cross , you know . you must know , however . you must not be _UNK by your asking him by her husband 's beauty . i am happier even than ever to do . you have widely _UNK it ; and i can congratulate your aunt . '' and i was not of so much _UNK , and repeat all the collinses , if the first tumult and three-and-twenty _UNK which she felt to have the happiest share of its affection , or the mantelpiece , which was a great _UNK to her mother 's being in a neighbouring situation to make him _UNK with her , and her own _UNK _UNK with the _UNK _UNK of visiting with him from the season and courtship _UNK to her husband 's being quite extravagant ; and , though she was still _UNK in her own room , there was no less _UNK on her mother 's incredulity ; but she was too much disposed for nothing as ever was so _UNK in so _UNK a man . she had not yet seen him so much , that her husband 's letter
# Example 8 generated:
# <s> but i have been mistaken with him at present . but tell me that you can not have the grief which _UNK , and the _UNK _UNK of her husband 's _UNK . the _UNK wish of a _UNK , the son which the unsettled _UNK which had been of his wife , she dropt no actual four months , she was very little mortified , and unable with place , however ; but she had no longer _UNK whether he was not of the habit of giving her more elegant , and talked , less irritable , was not in the respect which elizabeth explained in momentary desire of a man in her own private fortune . the _UNK wish , however to elizabeth had always made her _UNK , she could have a chaise ; and though she considered that he had been rendered in the room , and the others , and got all her own , and got a _UNK which she could not have prevailed in her own fortune , she could not listen for the evening at all , however . she was always of his temper ; and she could not determine whether she could not speak over her work in the room . the _UNK letter which elizabeth received on his _UNK , and _UNK , _UNK _UNK . elizabeth 's good humour . she had always been able to say that she had never seen a _UNK . she was in the bingleys . she is the _UNK , hypocritical woman . i am glad of it . you will not go from your sisters , and repeat all his manners . you were not so mean , you must not be so happy as to make the trouble and yours , which i have bought your having always paid him ; but now to see the _UNK , and the chosen _UNK , which i can not help writing me in her husband . you must go round , therefore and enjoy the room , for the sake of a good deal , amiable which she had been always so early from his own , that the _UNK letter to her mother 's _UNK to the advantage and spending less _UNK , to _UNK from her brother 's being quite extravagant ; and , though the others were _UNK by the match . elizabeth was delighted , and the morrow were in a neighbouring _UNK to town , and the accomplishment which her affection to her father 's society , and her manners , though the _UNK of living on the north , and the assurance of the five thousand _UNK from the influence of her nephew , whose manners were so unequal and gaiety , which she had yet been so mean from a _UNK which she received himself ; though she was in the point which elizabeth had been so _UNK as to overcome . but she was
# Example 9 generated:
# <s> but , my sweetest lizzy . if your sister must be in town , i am happier than to think of her family ; but i am happier even , i hope it is a young time , indeed , and despised . you must not have the grief of seeing you all . your mind is very well ; for she loves to be the _UNK , i believe ; but the _UNK was so well known as in his _UNK . you must go directly to mrs. long as much as they were . it is not to make us so happy an object as you have been _UNK by his _UNK ; for in the course of her meetings , i must confess it to do . i am sure you can not help writing him your own daughters . but now , if i had not given you all the preference , you thoroughly despised you all . but i dare say i have no reason for _his_ life , if you have been _UNK from the _UNK of his _UNK , and i dare say you will not be so reasonable . it would not have hated me in the _UNK manner of his own , nor _UNK as a _UNK as arising . i have been so mean from you ! but now ! i was sure i sha , in all my disposition and four . you were so rich ! i have saved you so much more ! what did i think it ? i am happier , '' replied her mother ; and she was still more than _UNK . but _now_ suppose it to have nothing more to speak for , or her agitation . he bore every letter , she was not in a humour for gaiety ; but the _UNK of her own _UNK . the gentlemen were _UNK , and her temper to make her _UNK , and the assurance of their sisters were a _UNK of good understanding to the _UNK and _UNK of his _UNK , or _UNK all the _UNK . the _UNK wish of her sisters sunk on the world . the ladies had received , that her husband was obliged that she should be prevailed at her own , she had been able that he would have been able for herself to speak with the evening when he complimented her , and her agitation in seeing her must be so much as to be so _UNK to such happy attention , or the promise of her mother and lydia 's example ; but , though the evening were still more than usual as ever as to be so _UNK as as to make any credit to their aunt and her husband 's being so frequently as to make her _UNK from her husband 's , it was not so exceedingly abusive ; for , as to the _UNK of his _UNK and

# %%
## Question 4
net = torch.load(PATH+'model_save_25.pt')
net.eval()
test_loss, perplexity = test(net, 'test_1.txt')
print('test loss {:5.2f} | test perplexity {:8.2f}'.format(test_loss.item(), perplexity))
# Out:
# test loss  5.50 | test perplexity   243.61

# %%
## Question 5
net = torch.load(PATH+'model_save_5.pt') # best model
net.eval()
test_loss, perplexity = test(net, 'test_2.txt')
print('test loss {:5.2f} | test perplexity {:8.2f}'.format(test_loss.item(), perplexity))
# Out:
# test loss  6.22 | test perplexity   504.26

# %%
## Question 6
max_len_seq = 5 # best model
text_train, label_train, vocab_size, encod, unencod, weights_matrix, words = processing(raw_text.copy(), max_len_seq, True, True)
# Out:
# ---- Result after tokenization
# Length words: 6553
# words: Counter({',': 9129, '.': 5047, 'the': 4331, 'to': 4137, 'of': 3608, 'and': 3577, 'her': 2203, 'i': 2064, 'a': 1947, 'in': 1865, 'was': 1844, '``': 1785, "''": 1747, 'she': 1695, 'that': 1540, ';': 1538, 'it': 1535, 'not': 1533, 'you': 1326, 'he': 1324, 'his': 1258, 'be': 1240, 'as': 1179, 'had': 1172, 'for': 1058, 'with': 1051, 'but': 1002, 'is': 860, 'have': 840, 'at': 788, 'mr.': 764, 'him': 753, 'on': 716, 'my': 703, "'s": 648, 'by': 635, 'elizabeth': 635, 'all': 621, 'they': 597, 'so': 589, 'were': 563, 'which': 538, 'could': 525, 'been': 515, '!': 499, 'from': 493, 'no': 490, 'very': 485, 'what': 478, 'would': 468, '?': 462, 'this': 441, 'their': 441, 'your': 440, 'me': 429, 'them': 429, 'darcy': 417, 'will': 404, 'said': 401, '--': 394, 'such': 386, 'when': 373, 'an': 354, 'if': 350, 'there': 348, 'do': 347, 'mrs.': 341, 'are': 338, 'much': 326, 'bennet': 323, 'more': 323, 'can': 322, 'am': 316, 'must': 305, 'bingley': 305, 'or': 300, 'jane': 291, 'who': 284, 'miss': 283, 'than': 282, 'any': 268, 'one': 267, 'did': 266, 'we': 247, 'should': 245, 'know': 236, 'how': 231, 'before': 227, 'herself': 227, 'though': 226, 'has': 221, 'never': 218, 'soon': 216, 'sister': 216, 'only': 215, 'well': 214, 'think': 211, 'other': 210, 'some': 207, 'now': 204, 'time': 200, 'might': 200, 'after': 199, 'every': 198, 'wickham': 194, 'may': 191, 'lady': 190, 'little': 188, 'most': 187, 'good': 183, 'own': 182, 'collins': 180, 'nothing': 177, 'again': 177, 'then': 174, 'being': 174, 'without': 171, 'lydia': 170, 'make': 165, 'shall': 161, 'say': 160, 'dear': 158, 'family': 151, 'man': 150, 'see': 149, 'first': 145, 'into': 142, 'great': 141, 'too': 141, 'father': 135, 'however': 134, 'mother': 134, 'day': 133, ':': 133, 'two': 132, 'out': 132, 'young': 130, 'ever': 130, 'himself': 127, 'made': 126, 'catherine': 126, 'give': 123, 'about': 122, 'hope': 121, 'us': 121, 'last': 119, 'always': 119, 'many': 119, 'away': 117, 'letter': 115, 'long': 114, 'friend': 112, 'room': 112, 'thought': 112, 'up': 111, 'way': 108, 'enough': 106, 'house': 106, 'its': 105, 'go': 104, 'replied': 103, 'saw': 103, 'sure': 102, 'manner': 99, 'felt': 99, 'lizzy': 97, 'wish': 97, 'gardiner': 97, 'quite': 96, 'indeed': 95, 'having': 95, 'oh': 94, 'come': 93, 'till': 93, 'myself': 93, 'better': 92, 'pleasure': 92, 'done': 92, 'cried': 91, 'love': 91, 'came': 90, 'over': 89, 'often': 89, 'where': 89, 'really': 88, 'longbourn': 88, 'believe': 87, 'feelings': 86, 'daughter': 85, 'charlotte': 85, 'heard': 84, 'subject': 84, 'whom': 84, 'aunt': 84, 'does': 83, 'happy': 83, 'even': 82, 'take': 80, 'anything': 80, 'morning': 79, 'whole': 79, 'sir': 78, 'like': 77, 'less': 77, 'perhaps': 76, 'sisters': 76, 'upon': 76, 'seen': 76, 'let': 75, 'therefore': 75, 'while': 75, 'brother': 75, 'yes': 75, 'our': 74, 'evening': 74, 'ladies': 74, 'looked': 74, 'netherfield': 73, 'just': 73, 'down': 73, 'place': 73, 'nor': 73, 'yet': 73, 'still': 72, 'certainly': 72, 'happiness': 72, 'tell': 71, 'next': 71, 'few': 71, 'something': 71, 'kitty': 71, 'hear': 71, 'added': 71, 'both': 71, 'lucas': 70, 'moment': 70, 'told': 69, 'these': 69, 'same': 69, 'opinion': 68, 'attention': 68, 'uncle': 68, 'here': 67, 'towards': 67, 'present': 67, 'went': 67, 'speak': 66, 'world': 66, 'found': 66, 'seemed': 66, 'home': 66, 'marriage': 66, 'colonel': 66, 'answer': 65, 'least': 65, 'left': 65, 'character': 64, 'town': 64, 'together': 64, 'between': 63, 'each': 63, 'gone': 62, 'off': 62, 'because': 62, 'married': 61, 'conversation': 61, 'passed': 61, 'leave': 61, 'kind': 61, 'received': 61, 'immediately': 60, 'part': 60, 'seeing': 60, 'coming': 60, 'woman': 59, 'since': 59, 'those': 59, 'began': 59, 'either': 59, 'whose': 59, 'almost': 59, 'find': 58, 'affection': 58, 'far': 58, 'known': 57, 'party': 57, 'mind': 57, 'knew': 57, 'once': 57, 'going': 57, 'means': 57, 'look': 57, 'meryton': 57, 'three': 57, 'life': 56, 'another': 56, 'possible': 56, 'friends': 55, 'certain': 55, 'london': 55, 'rather': 5 ...
# text: [['<s>', 'it', 'is', 'a', 'truth', 'universally', 'acknowledged', ',', 'that', 'a', 'single', 'man', 'in', 'possession', 'of', 'a', 'good', 'fortune', ',', 'must', 'be', 'in', 'want', 'of', 'a', 'wife', '.', '</s>'], ['<s>', 'however', 'little', 'known', 'the', 'feelings', 'or', 'views', 'of', 'such', 'a', 'man', 'may', 'be', 'on', 'his', 'first', 'entering', 'a', 'neighbourhood', ',', 'this', 'truth', 'is', 'so', 'well', 'fixed', 'in', 'the', 'minds', 'of', 'the', 'surrounding', 'families', ',', 'that', 'he', 'is', 'considered', 'the', 'rightful', 'property', 'of', 'some', 'one', 'or', 'other', 'of', 'their', 'daughters', '.', '</s>']]
#
# ---- Result after reorganizing by sequences
# text: [['<s>', 'it', 'is', 'a', 'truth', 'universally'], ['it', 'is', 'a', 'truth', 'universally', 'acknowledged']]
# len(text): 137164
# max_len_seq: 5
# ok
# Word found in glove: 6143/6557
#
# ---- Result after encoding
# text_train: [[2, 20, 31, 12, 539, 2433], [20, 31, 12, 539, 2433, 696]]
#
# ---- Result after padding
# text_train: [[2, 20, 31, 12, 539, 2433], [20, 31, 12, 539, 2433, 696]]
#
# ---- Result after creating x and y
# text_train: [[   2   20   31   12  539]
#  [  20   31   12  539 2433]]
# label_train: [[  20   31   12  539 2433]
#  [  31   12  539 2433  696]]
# vocab size: 6557

# %%
net = WordLSTM(mode='glove', weights_matrix=weights_matrix).cuda()
print(net)
train(net, text_train, label_train, batch_size = 32, epochs=20, print_every=4000)
torch.save(net, PATH+'model_glove_5.pt')
# Out:
# vocab_size  6557
# WordLSTM(
#   (emb_layer): Embedding(6557, 100)
#   (lstm): LSTM(100, 256, num_layers=4, batch_first=True, dropout=0.3)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=256, out_features=6557, bias=True)
# )
# Epoch: 1/20... Loss: 5.633097...
# Epoch: 2/20... Loss: 5.360171...
# Epoch: 3/20... Loss: 4.998235...
# Epoch: 4/20... Loss: 4.839860...
# Epoch: 5/20... Loss: 4.524868...
# Epoch: 6/20... Loss: 4.585644...
# Epoch: 7/20... Loss: 4.572575...
# Epoch: 8/20... Loss: 4.415634...
# Epoch: 9/20... Loss: 4.346293...
# Epoch: 10/20... Loss: 4.271797...
# Epoch: 11/20... Loss: 4.151351...
# Epoch: 12/20... Loss: 4.199869...
# Epoch: 13/20... Loss: 4.229291...
# Epoch: 14/20... Loss: 4.095868...
# Epoch: 15/20... Loss: 4.047168...
# Epoch: 16/20... Loss: 4.127080...
# Epoch: 17/20... Loss: 4.079382...
# Epoch: 18/20... Loss: 4.009870...
# Epoch: 19/20... Loss: 3.988736...
# Epoch: 20/20... Loss: 3.884956...

# %%
net = torch.load(PATH+'model_glove_5.pt')
net.eval()
for i in range(10):
    print("Example {} generated: ".format(i))
    print(sample(net, 500, encod, unencod, prime = "<s>"))
# Out:
# Example 0 generated:
# <s> you will have hated him to be done to be done , i shall not have the grief of his forbearance , she could not be in her power , by the practice of his friend . she could not help him a hint of his friend , he had no longer kept her , she could not be prevailed by him . she was not so happy , but the comfort was not so little , she was in the bingleys ; for the next of her daughters ; for she could not be prevailed , and the evening , he could have been more welcome to her , and her manners were a little kinder , tax to her husband ; but , as she could have been able for her . she could have no compassion for the marriage , and the other of them ; but elizabeth , in the room ; but it would not have relished her to the woods , and the others , and the world of her letter was now gratified to get a twelvemonth to the world ; and though she did not listen , was still relieved with the extreme of his wife , and she was not in a humour to be so happy as to make him the last , she had not known , she could not help him the last , and she had no longer anxious . the world , and she was to see the persons , and the morrow , she was to be a little kinder answer , when the chief was not so happy , but , to the contrary of the persons . she could not help liberties to her husband . she could have no objection , she had been in her power for the bingleys was in the future , she was always moving to a cheap desire of her own , he could not be in a little further , she was prevailed to the last day , and she had been the first vehemence , she had not more anxious than the bingleys was in a few lines , and she could have given her , she could be filling from his marriage . </s>
# Example 1 generated:
# <s> it is a good comfort of his own , and she could not have the last , and the girls were always in her power , was in spite , by the middle of her own room . </s>
# Example 2 generated:
# <s> i are not to have the world of your dear jane , '' she added . `` you are a great deal of paper to the world . but i do not know how much it would have hated him to the truth , i shall not help writing to the season . </s>
# Example 3 generated:
# <s> it can have given him , if you will be sure , '' she added . </s>
# Example 4 generated:
# <s> it can be quite much , but you must have given me pain . i am afraid of her . but it was very little . '' </s>
# Example 5 generated:
# <s> i have been so much reasonable , i shall not help thanking me , and the comfort to his wife 's situation . she could be in the world . '' said he , with proper frankness , and pronouncing her mother . she wrote , and her husband had not been more anxious to mix to the day , she could have no longer kept her , was not merely to the greater frankness to elizabeth was gone down . </s>
# Example 6 generated:
# <s> i are a very beginning , and , to the comfort , and the report , and her husband , and she could have no objection for her , she could be vulgar to him . she could not be prevailed , but the morrow were in the neighbourhood ; but she had not known him to her , she had not been in her own feelings ; for the first , but , though she was in the world . she had no longer anxious . she had always been so tiresome as abhorrence . the darling , and the world , and she could have been able for her . </s>
# Example 7 generated:
# <s> you are too good , i shall not have been so silly as to be so much awe , i hope , and i was so much reasonable . '' </s>
# Example 8 generated:
# <s> you must not be more , to be afraid of it , and i hope you are not so unwilling to have a value to you must not be able , and she could not have the meaning to the north of his own . she had always been over-rated , she retained him to the next day , he had been in her power to make the truth , to be sent on , to the first , she had been a little longer in love to the end of his wife , she was not likely to mix of her own , he was not to have the pleasure to the rest of her heart ; but , in spite to her sister . </s>
# Example 9 generated:
# <s> you must be so well known to you . '' and , perhaps . '' she added . </s>

# %%
## Question 7
net = torch.load(PATH+'model_glove_5.pt') # best model
net.eval()
test_loss, perplexity = test(net, 'test_1.txt')
print('test loss {:5.2f} | test perplexity {:8.2f}'.format(test_loss.item(), perplexity))
# Out:
# test loss  6.54 | test perplexity   689.15

# %%
## Question 8 TWEET
max_len_seq = 5
text_train, label_train, vocab_size, encod, unencod, _, words = processing(raw_tweet.copy(), max_len_seq, False, False)
print(encod)
# Out:
# ---- Result after tokenization
# Length words: 12630
# words: Counter({'<s>': 6000, '</s>': 6000, 'i': 3697, '!': 3138, '.': 3088, '"': 2670, 'to': 2281, 'the': 1898, ',': 1897, 'a': 1391, 'it': 1172, 'and': 1132, 'you': 1130, 'my': 1097, 'is': 916, '?': 859, 'in': 854, '...': 828, 'for': 817, 'of': 725, "n't": 678, 'that': 652, 'on': 632, 'have': 623, "'s": 617, 'me': 558, 'so': 534, 'do': 514, 'but': 511, 'just': 463, '-': 457, 'not': 450, "'m": 438, 'was': 431, 'be': 416, 'at': 403, 'with': 385, 'good': 374, 'this': 365, 'now': 357, '..': 354, 'up': 353, ';': 324, '&': 323, 'are': 321, 'all': 318, 'day': 317, 'go': 300, 'out': 295, 'work': 292, 'like': 287, 'get': 277, 'back': 268, 'today': 261, 'time': 257, 'going': 257, 'too': 254, 'got': 253, 'no': 252, 'what': 248, 'we': 247, 'ca': 241, 'your': 234, 'nt': 226, 'love': 222, 'one': 216, 'lol': 213, 'about': 207, 'am': 205, 'know': 195, 'from': 194, 'night': 193, 'will': 187, 'can': 182, 'had': 181, 'if': 181, 'did': 178, 'really': 177, 'tomorrow': 177, 'want': 172, 'well': 171, 'see': 170, 'm': 169, 'some': 169, 'u': 168, 'still': 168, 'its': 165, '2': 161, 'how': 156, 'morning': 156, 'as': 155, 'an': 153, 'oh': 152, 'twitter': 151, 'when': 151, 'more': 148, 'thanks': 147, 'there': 146, "'ll": 143, 'much': 141, 'new': 141, 'then': 140, '....': 140, 'off': 140, "'": 140, 'think': 139, 'need': 138, 'bed': 137, 'they': 137, 'or': 134, 'home': 134, 'amp': 133, 'he': 130, ')': 130, 'again': 130, 'here': 128, 'hope': 128, 'sleep': 128, '(': 127, 'last': 125, 'school': 124, 'feel': 121, 'would': 120, 'only': 118, 'has': 117, ':': 117, 'great': 115, 'does': 113, 'should': 112, 'been': 110, 'miss': 109, "'re": 105, '#': 105, "'ve": 104, 'could': 103, 'haha': 102, 'week': 102, 'very': 101, '*': 101, 'sad': 101, 'over': 100, 'wish': 100, 'nice': 99, 'better': 98, 'days': 98, 'fun': 96, 'come': 95, 'by': 93, 'make': 92, 'why': 92, 'best': 91, 'getting': 90, 'her': 90, 'bad': 89, 'way': 87, 'them': 85, 'please': 84, 'wait': 82, 'next': 82, 'na': 81, 'right': 80, 'who': 80, '/': 79, 'though': 79, 'made': 79, 'happy': 78, 'gon': 78, 'she': 77, 'sorry': 77, 'ok': 77, 'life': 76, 'yes': 76, 'watching': 75, 'long': 74, 'yeah': 72, 'done': 72, 'doing': 71, 'hate': 71, 'weekend': 71, 'take': 70, 'working': 69, 'another': 69, 'than': 67, 'even': 67, 'always': 67, 'hey': 66, '4': 66, 'man': 66, '3': 65, 'find': 64, 'soon': 64, 'trying': 64, 'everyone': 63, 'him': 63, 'already': 63, 's': 63, 'never': 63, 'feeling': 62, 'first': 62, 'maybe': 62, 'us': 62, 'people': 61, 'something': 61, 'show': 60, 'wo': 60, 'down': 60, 'tired': 60, 'thank': 60, 'were': 59, 'say': 59, 'awesome': 59, 'his': 59, 'tonight': 58, 'into': 58, 'cool': 58, 'any': 57, 'glad': 56, 'sure': 55, 'look': 55, '�': 55, 'after': 55, 'having': 54, 'thing': 54, 'keep': 54, 'watch': 53, 'little': 53, 'sick': 52, 'early': 52, 'our': 52, 'two': 51, 'looking': 51, 'left': 51, 'being': 50, 'yay': 50, 'let': 48, "'d": 48, 'wanna': 48, 'few': 48, 'house': 48, 'guys': 47, 'because': 47, 'damn': 47, 'pretty': 47, 'sunday': 47, 'try': 46, 'break': 46, 'help': 45, 'use': 45, 'finally': 44, 'late': 44, 'sucks': 44, 'big': 44, '1': 44, 'missed': 44, 'stuff': 44, 'lost': 43, 'ur': 43, 'things': 43, 'old': 43, 'amazing': 43, 'actually': 43, 'away': 43, 'hours': 42, 'goodnight': 42, 'put': 42, 'other': 42, 'movie': 42, 'before': 42, 'saw': 42, 'luck': 42, 'weeks': 42, 'start': 42, 'same': 41, 'phone': 41, 'read': 41, 'bored': 41, 'guess': 41, 'where': 41, 'wow': 41, 'someone': 41, 'world': 41, 'tell': 40, 'makes': 40, 'sweet': 39, 'omg': 39, '@jonathanrknight': 39, 'those': 39, 'excited': 39, 'god': 39, 'ever': 39, 'forward': 39, 'ready': 39, 'end': 39, 'ugh': 39, 'thought': 38, 'game': 38, 'nothing': 38, 'until': 38, '@': 38, 'such': 38, 'hard': 38, 'friends': 37, 'went': 37, 'music': 37, 'till': 37, '5': 37, 'lot': 37, 'sun': 37, 'bit': 37, 'real': 36, 'yet': 36, 'spring': 36, 'also': 36, 'follow': 36, 'n': 36, 'ta': 36, 'eat': 35, 'around': 35, 'found': 35, 'hear': 35, 'hot': 35, 'check': 35, 'mean ...
# text: [['<s>', 'i', 'love', '@health4uandpets', 'u', 'guys', 'r', 'the', 'best', '!', '!', '</s>'], ['<s>', 'i', 'm', 'meeting', 'up', 'with', 'one', 'of', 'my', 'besties', 'tonight', '!', 'ca', 'nt', 'wait', '!', '!', '-', 'girl', 'talk', '!', '!', '</s>']]
#
# ---- Result after reorganizing by sequences
# text: [['<s>', 'i', 'love', '@health4uandpets', 'u', 'guys'], ['i', 'love', '@health4uandpets', 'u', 'guys', 'r']]
# len(text): 78861
# max_len_seq: 5
#
# ---- Result after encoding
# text_train: [[2, 4, 66, 1, 86, 241], [4, 66, 1, 86, 241, 329]]
#
# ---- Result after padding
# text_train: [[2, 4, 66, 1, 86, 241], [4, 66, 1, 86, 241, 329]]
#
# ---- Result after creating x and y
# text_train: [[  2   4  66   1  86]
#  [  4  66   1  86 241]]
# label_train: [[  4  66   1  86 241]
#  [ 66   1  86 241 329]]
# vocab size: 3997
# {'_PAD': 0, '_UNK': 1, '<s>': 2, '</s>': 3, 'i': 4, '!': 5, '.': 6, '"': 7, 'to': 8, 'the': 9, ',': 10, 'a': 11, 'it': 12, 'and': 13, 'you': 14, 'my': 15, 'is': 16, '?': 17, 'in': 18, '...': 19, 'for': 20, 'of': 21, "n't": 22, 'that': 23, 'on': 24, 'have': 25, "'s": 26, 'me': 27, 'so': 28, 'do': 29, 'but': 30, 'just': 31, '-': 32, 'not': 33, "'m": 34, 'was': 35, 'be': 36, 'at': 37, 'with': 38, 'good': 39, 'this': 40, 'now': 41, '..': 42, 'up': 43, ';': 44, '&': 45, 'are': 46, 'all': 47, 'day': 48, 'go': 49, 'out': 50, 'work': 51, 'like': 52, 'get': 53, 'back': 54, 'today': 55, 'time': 56, 'going': 57, 'too': 58, 'got': 59, 'no': 60, 'what': 61, 'we': 62, 'ca': 63, 'your': 64, 'nt': 65, 'love': 66, 'one': 67, 'lol': 68, 'about': 69, 'am': 70, 'know': 71, 'from': 72, 'night': 73, 'will': 74, 'can': 75, 'had': 76, 'if': 77, 'did': 78, 'really': 79, 'tomorrow': 80, 'want': 81, 'well': 82, 'see': 83, 'm': 84, 'some': 85, 'u': 86, 'still': 87, 'its': 88, '2': 89, 'how': 90, 'morning': 91, 'as': 92, 'an': 93, 'oh': 94, 'twitter': 95, 'when': 96, 'more': 97, 'thanks': 98, 'there': 99, "'ll": 100, 'much': 101, 'new': 102, 'then': 103, '....': 104, 'off': 105, "'": 106, 'think': 107, 'need': 108, 'bed': 109, 'they': 110, 'or': 111, 'home': 112, 'amp': 113, 'he': 114, ')': 115, 'again': 116, 'here': 117, 'hope': 118, 'sleep': 119, '(': 120, 'last': 121, 'school': 122, 'feel': 123, 'would': 124, 'only': 125, 'has': 126, ':': 127, 'great': 128, 'does': 129, 'should': 130, 'been': 131, 'miss': 132, "'re": 133, '#': 134, "'ve": 135, 'could': 136, 'haha': 137, 'week': 138, 'very': 139, '*': 140, 'sad': 141, 'over': 142, 'wish': 143, 'nice': 144, 'better': 145, 'days': 146, 'fun': 147, 'come': 148, 'by': 149, 'make': 150, 'why': 151, 'best': 152, 'getting': 153, 'her': 154, 'bad': 155, 'way': 156, 'them': 157, 'please': 158, 'wait': 159, 'next': 160, 'na': 161, 'right': 162, 'who': 163, '/': 164, 'though': 165, 'made': 166, 'happy': 167, 'gon': 168, 'she': 169, 'sorry': 170, 'ok': 171, 'life': 172, 'yes': 173, 'watching': 174, 'long': 175, 'yeah': 176, 'done': 177, 'doing': 178, 'hate': 179, 'weekend': 180, 'take': 181, 'working': 182, 'another': 183, 'than': 184, 'even': 185, 'always': 186, 'hey': 187, '4': 188, 'man': 189, '3': 190, 'find': 191, 'soon': 192, 'trying': 193, 'everyone': 194, 'him': 195, 'already': 196, 's': 197, 'never': 198, 'feeling': 199, 'first': 200, 'maybe': 201, 'us': 202, 'people': 203, 'something': 204, 'show': 205, 'wo': 206, 'down': 207, 'tired': 208, 'thank': 209, 'were': 210, 'say': 211, 'awesome': 212, 'his': 213, 'tonight': 214, 'into': 215, 'cool': 216, 'any': 217, 'glad': 218, 'sure': 219, 'look': 220, '�': 221, 'after': 222, 'having': 223, 'thing': 224, 'keep': 225, 'watch': 226, 'little': 227, 'sick': 228, 'early': 229, 'our': 230, 'two': 231, 'looking': 232, 'left': 233, 'being': 234, 'yay': 235, 'let': 236, "'d": 237, 'wanna': 238, 'few': 239, 'house': 240, 'guys': 241, 'because': 242, 'damn': 243, 'pretty': 244, 'sunday': 245, 'try': 246, 'break': 247, 'help': 248, 'use': 249, 'finally': 250, 'late': 251, 'sucks': 252, 'big': 253, '1': 254, 'missed': 255, 'stuff': 256, 'lost': 257, 'ur': 258, 'things': 259, 'old': 260, 'amazing': 261, 'actually': 262, 'away': 263, 'hours': 264, 'goodnight': 265, 'put': 266, 'other': 267, 'movie': 268, 'before': 269, 'saw': 270, 'luck': 271, 'weeks': 272, 'start': 273, 'same': 274, 'phone': 275, 'read': 276, 'bored': 277, 'guess': 278, 'where': 279, 'wow': 280, 'someone': 281, 'world': 282, 'tell': 283, 'makes': 284, 'sweet': 285, 'omg': 286, '@jonathanrknight': 287, 'those': 288, 'excited': 289, 'god': 290, 'ever': 291, 'forward': 292, 'ready': 293, 'end': 294, 'ugh': 295, 'thought': 296, 'game': 297, 'nothing': 298, 'until': 299, '@': 300, 'such': 301, 'hard': 302, 'friends': 303, 'went': 304, 'music': 305, 'till': 306, '5': 307, 'lot': 308, 'sun': 309, 'bit': 310, 'real': 311, 'yet': 312, 'spring': 313, 'also': 314, 'follow': 315, 'n': 316, 'ta': 317, 'eat': 318, 'aroun ...

# %%
net = WordLSTM().cuda()
train(net, text_train, label_train, batch_size = 32, epochs=20, print_every=4000)
torch.save(net, PATH+'model_tweet_5.pt')
# Out:
# vocab_size  3997
# Epoch: 1/20... Loss: 5.252578...
# Epoch: 2/20... Loss: 4.897115...
# Epoch: 3/20... Loss: 4.688882...
# Epoch: 4/20... Loss: 4.531646...
# Epoch: 5/20... Loss: 4.405295...
# Epoch: 6/20... Loss: 4.388572...
# Epoch: 7/20... Loss: 4.270437...
# Epoch: 8/20... Loss: 4.183468...
# Epoch: 9/20... Loss: 4.147174...
# Epoch: 10/20... Loss: 4.200684...
# Epoch: 11/20... Loss: 4.059154...
# Epoch: 12/20... Loss: 3.903972...
# Epoch: 13/20... Loss: 3.769385...
# Epoch: 14/20... Loss: 3.831891...
# Epoch: 15/20... Loss: 3.742058...
# Epoch: 16/20... Loss: 3.658604...
# Epoch: 17/20... Loss: 3.645605...
# Epoch: 18/20... Loss: 3.737691...
# Epoch: 19/20... Loss: 3.544748...
# Epoch: 20/20... Loss: 3.611055...

# %%
net = torch.load(PATH+'model_tweet_5.pt')
net.eval()
for i in range(10):
    print("Example {} generated: ".format(i))
    print(sample(net, 500, encod, unencod, prime = "<s>"))
# Out:
# Example 0 generated:
# <s> _UNK _ _UNK , but still not a closet i do not want to get @aubreyoday to be _UNK _UNK , _UNK _UNK _UNK . _UNK arnt * _UNK ) * i do nt get to get to see _UNK . _UNK . nyte feeling a bit _UNK , but i do n't have any idea how a homo . </s>
# Example 1 generated:
# <s> " i hate _UNK . </s>
# Example 2 generated:
# <s> _UNK _UNK i 'm not going back 2 skool i m so jealous ! i have n't eaten at my _UNK _UNK _UNK . i m not _UNK . _UNK . i m pretty _UNK , but i m not not a closet break at work . i m going back to work tomorrow , i m going to sleep . </s>
# Example 3 generated:
# <s> " _UNK oh hun ! ! i 'm a bit _UNK , i do not get a virus ! i have to go back for a sleep </s>
# Example 4 generated:
# <s> i 'm not going to be _UNK by the _UNK of my _UNK . i m not _UNK , _UNK . i m pretty sad , i 'm a _UNK _UNK _UNK , i ca n't sleep . " </s>
# Example 5 generated:
# <s> i m so tired . i have n't slept awake to go to school tomorrow . </s>
# Example 6 generated:
# <s> " just _UNK _UNK _UNK . _UNK arnt _UNK _UNK _UNK , i ca n't get a teacher ! ! </s>
# Example 7 generated:
# <s> i have n't been able for a _UNK chat now " i m so sad . i have to go home . i m not a closet day . " i have to wake my life ! ! i 'm not _UNK _UNK _UNK . _UNK arnt * i do n't have a _UNK . _UNK _UNK . _UNK arnt </s>
# Example 8 generated:
# <s> i m so tired ! ! i 'm so tired . " hating _UNK , _UNK . " </s>
# Example 9 generated:
# <s> " _UNK _UNK _UNK ! ! _UNK ! i 'm so jealous ! </s>

# %%
## Question 9
net = torch.load(PATH+'model_tweet_5.pt')
net.eval()
test_loss, perplexity = test(net, 'test_2.txt')
print('test loss {:5.2f} | test perplexity {:8.2f}'.format(test_loss.item(), perplexity))
# Out:
# test loss  4.78 | test perplexity   119.45

# %%
## Question 10
max_len_seq = 15
text_train, label_train, vocab_size, encod, unencod, _, words = processing(raw_tweet.copy(), max_len_seq, False, False)
print(encod)
# Out:
# ---- Result after tokenization
# Length words: 12630
# words: Counter({'<s>': 6000, '</s>': 6000, 'i': 3697, '!': 3138, '.': 3088, '"': 2670, 'to': 2281, 'the': 1898, ',': 1897, 'a': 1391, 'it': 1172, 'and': 1132, 'you': 1130, 'my': 1097, 'is': 916, '?': 859, 'in': 854, '...': 828, 'for': 817, 'of': 725, "n't": 678, 'that': 652, 'on': 632, 'have': 623, "'s": 617, 'me': 558, 'so': 534, 'do': 514, 'but': 511, 'just': 463, '-': 457, 'not': 450, "'m": 438, 'was': 431, 'be': 416, 'at': 403, 'with': 385, 'good': 374, 'this': 365, 'now': 357, '..': 354, 'up': 353, ';': 324, '&': 323, 'are': 321, 'all': 318, 'day': 317, 'go': 300, 'out': 295, 'work': 292, 'like': 287, 'get': 277, 'back': 268, 'today': 261, 'time': 257, 'going': 257, 'too': 254, 'got': 253, 'no': 252, 'what': 248, 'we': 247, 'ca': 241, 'your': 234, 'nt': 226, 'love': 222, 'one': 216, 'lol': 213, 'about': 207, 'am': 205, 'know': 195, 'from': 194, 'night': 193, 'will': 187, 'can': 182, 'had': 181, 'if': 181, 'did': 178, 'really': 177, 'tomorrow': 177, 'want': 172, 'well': 171, 'see': 170, 'm': 169, 'some': 169, 'u': 168, 'still': 168, 'its': 165, '2': 161, 'how': 156, 'morning': 156, 'as': 155, 'an': 153, 'oh': 152, 'twitter': 151, 'when': 151, 'more': 148, 'thanks': 147, 'there': 146, "'ll": 143, 'much': 141, 'new': 141, 'then': 140, '....': 140, 'off': 140, "'": 140, 'think': 139, 'need': 138, 'bed': 137, 'they': 137, 'or': 134, 'home': 134, 'amp': 133, 'he': 130, ')': 130, 'again': 130, 'here': 128, 'hope': 128, 'sleep': 128, '(': 127, 'last': 125, 'school': 124, 'feel': 121, 'would': 120, 'only': 118, 'has': 117, ':': 117, 'great': 115, 'does': 113, 'should': 112, 'been': 110, 'miss': 109, "'re": 105, '#': 105, "'ve": 104, 'could': 103, 'haha': 102, 'week': 102, 'very': 101, '*': 101, 'sad': 101, 'over': 100, 'wish': 100, 'nice': 99, 'better': 98, 'days': 98, 'fun': 96, 'come': 95, 'by': 93, 'make': 92, 'why': 92, 'best': 91, 'getting': 90, 'her': 90, 'bad': 89, 'way': 87, 'them': 85, 'please': 84, 'wait': 82, 'next': 82, 'na': 81, 'right': 80, 'who': 80, '/': 79, 'though': 79, 'made': 79, 'happy': 78, 'gon': 78, 'she': 77, 'sorry': 77, 'ok': 77, 'life': 76, 'yes': 76, 'watching': 75, 'long': 74, 'yeah': 72, 'done': 72, 'doing': 71, 'hate': 71, 'weekend': 71, 'take': 70, 'working': 69, 'another': 69, 'than': 67, 'even': 67, 'always': 67, 'hey': 66, '4': 66, 'man': 66, '3': 65, 'find': 64, 'soon': 64, 'trying': 64, 'everyone': 63, 'him': 63, 'already': 63, 's': 63, 'never': 63, 'feeling': 62, 'first': 62, 'maybe': 62, 'us': 62, 'people': 61, 'something': 61, 'show': 60, 'wo': 60, 'down': 60, 'tired': 60, 'thank': 60, 'were': 59, 'say': 59, 'awesome': 59, 'his': 59, 'tonight': 58, 'into': 58, 'cool': 58, 'any': 57, 'glad': 56, 'sure': 55, 'look': 55, '�': 55, 'after': 55, 'having': 54, 'thing': 54, 'keep': 54, 'watch': 53, 'little': 53, 'sick': 52, 'early': 52, 'our': 52, 'two': 51, 'looking': 51, 'left': 51, 'being': 50, 'yay': 50, 'let': 48, "'d": 48, 'wanna': 48, 'few': 48, 'house': 48, 'guys': 47, 'because': 47, 'damn': 47, 'pretty': 47, 'sunday': 47, 'try': 46, 'break': 46, 'help': 45, 'use': 45, 'finally': 44, 'late': 44, 'sucks': 44, 'big': 44, '1': 44, 'missed': 44, 'stuff': 44, 'lost': 43, 'ur': 43, 'things': 43, 'old': 43, 'amazing': 43, 'actually': 43, 'away': 43, 'hours': 42, 'goodnight': 42, 'put': 42, 'other': 42, 'movie': 42, 'before': 42, 'saw': 42, 'luck': 42, 'weeks': 42, 'start': 42, 'same': 41, 'phone': 41, 'read': 41, 'bored': 41, 'guess': 41, 'where': 41, 'wow': 41, 'someone': 41, 'world': 41, 'tell': 40, 'makes': 40, 'sweet': 39, 'omg': 39, '@jonathanrknight': 39, 'those': 39, 'excited': 39, 'god': 39, 'ever': 39, 'forward': 39, 'ready': 39, 'end': 39, 'ugh': 39, 'thought': 38, 'game': 38, 'nothing': 38, 'until': 38, '@': 38, 'such': 38, 'hard': 38, 'friends': 37, 'went': 37, 'music': 37, 'till': 37, '5': 37, 'lot': 37, 'sun': 37, 'bit': 37, 'real': 36, 'yet': 36, 'spring': 36, 'also': 36, 'follow': 36, 'n': 36, 'ta': 36, 'eat': 35, 'around': 35, 'found': 35, 'hear': 35, 'hot': 35, 'check': 35, 'mean ...
# text: [['<s>', 'i', 'love', '@health4uandpets', 'u', 'guys', 'r', 'the', 'best', '!', '!', '</s>'], ['<s>', 'i', 'm', 'meeting', 'up', 'with', 'one', 'of', 'my', 'besties', 'tonight', '!', 'ca', 'nt', 'wait', '!', '!', '-', 'girl', 'talk', '!', '!', '</s>']]
#
# ---- Result after reorganizing by sequences
# text: [['<s>', 'i', 'love', '@health4uandpets', 'u', 'guys', 'r', 'the', 'best', '!', '!', '</s>'], ['<s>', 'i', 'm', 'meeting', 'up', 'with', 'one', 'of', 'my', 'besties', 'tonight', '!', 'ca', 'nt', 'wait', '!']]
# len(text): 33931
# max_len_seq: 15
#
# ---- Result after encoding
# text_train: [[2, 4, 66, 1, 86, 241, 329, 9, 152, 5, 5, 3], [2, 4, 84, 606, 43, 38, 67, 21, 15, 1, 214, 5, 63, 65, 159, 5]]
#
# ---- Result after padding
# text_train: [[0, 0, 0, 0, 2, 4, 66, 1, 86, 241, 329, 9, 152, 5, 5, 3], [2, 4, 84, 606, 43, 38, 67, 21, 15, 1, 214, 5, 63, 65, 159, 5]]
#
# ---- Result after creating x and y
# text_train: [[  0   0   0   0   2   4  66   1  86 241 329   9 152   5   5]
#  [  2   4  84 606  43  38  67  21  15   1 214   5  63  65 159]]
# label_train: [[  0   0   0   2   4  66   1  86 241 329   9 152   5   5   3]
#  [  4  84 606  43  38  67  21  15   1 214   5  63  65 159   5]]
# vocab size: 3997
# {'_PAD': 0, '_UNK': 1, '<s>': 2, '</s>': 3, 'i': 4, '!': 5, '.': 6, '"': 7, 'to': 8, 'the': 9, ',': 10, 'a': 11, 'it': 12, 'and': 13, 'you': 14, 'my': 15, 'is': 16, '?': 17, 'in': 18, '...': 19, 'for': 20, 'of': 21, "n't": 22, 'that': 23, 'on': 24, 'have': 25, "'s": 26, 'me': 27, 'so': 28, 'do': 29, 'but': 30, 'just': 31, '-': 32, 'not': 33, "'m": 34, 'was': 35, 'be': 36, 'at': 37, 'with': 38, 'good': 39, 'this': 40, 'now': 41, '..': 42, 'up': 43, ';': 44, '&': 45, 'are': 46, 'all': 47, 'day': 48, 'go': 49, 'out': 50, 'work': 51, 'like': 52, 'get': 53, 'back': 54, 'today': 55, 'time': 56, 'going': 57, 'too': 58, 'got': 59, 'no': 60, 'what': 61, 'we': 62, 'ca': 63, 'your': 64, 'nt': 65, 'love': 66, 'one': 67, 'lol': 68, 'about': 69, 'am': 70, 'know': 71, 'from': 72, 'night': 73, 'will': 74, 'can': 75, 'had': 76, 'if': 77, 'did': 78, 'really': 79, 'tomorrow': 80, 'want': 81, 'well': 82, 'see': 83, 'm': 84, 'some': 85, 'u': 86, 'still': 87, 'its': 88, '2': 89, 'how': 90, 'morning': 91, 'as': 92, 'an': 93, 'oh': 94, 'twitter': 95, 'when': 96, 'more': 97, 'thanks': 98, 'there': 99, "'ll": 100, 'much': 101, 'new': 102, 'then': 103, '....': 104, 'off': 105, "'": 106, 'think': 107, 'need': 108, 'bed': 109, 'they': 110, 'or': 111, 'home': 112, 'amp': 113, 'he': 114, ')': 115, 'again': 116, 'here': 117, 'hope': 118, 'sleep': 119, '(': 120, 'last': 121, 'school': 122, 'feel': 123, 'would': 124, 'only': 125, 'has': 126, ':': 127, 'great': 128, 'does': 129, 'should': 130, 'been': 131, 'miss': 132, "'re": 133, '#': 134, "'ve": 135, 'could': 136, 'haha': 137, 'week': 138, 'very': 139, '*': 140, 'sad': 141, 'over': 142, 'wish': 143, 'nice': 144, 'better': 145, 'days': 146, 'fun': 147, 'come': 148, 'by': 149, 'make': 150, 'why': 151, 'best': 152, 'getting': 153, 'her': 154, 'bad': 155, 'way': 156, 'them': 157, 'please': 158, 'wait': 159, 'next': 160, 'na': 161, 'right': 162, 'who': 163, '/': 164, 'though': 165, 'made': 166, 'happy': 167, 'gon': 168, 'she': 169, 'sorry': 170, 'ok': 171, 'life': 172, 'yes': 173, 'watching': 174, 'long': 175, 'yeah': 176, 'done': 177, 'doing': 178, 'hate': 179, 'weekend': 180, 'take': 181, 'working': 182, 'another': 183, 'than': 184, 'even': 185, 'always': 186, 'hey': 187, '4': 188, 'man': 189, '3': 190, 'find': 191, 'soon': 192, 'trying': 193, 'everyone': 194, 'him': 195, 'already': 196, 's': 197, 'never': 198, 'feeling': 199, 'first': 200, 'maybe': 201, 'us': 202, 'people': 203, 'something': 204, 'show': 205, 'wo': 206, 'down': 207, 'tired': 208, 'thank': 209, 'were': 210, 'say': 211, 'awesome': 212, 'his': 213, 'tonight': 214, 'into': 215, 'cool': 216, 'any': 217, 'glad': 218, 'sure': 219, 'look': 220, '�': 221, 'after': 222, 'having': 223, 'thing': 224, 'keep': 225, 'watch': 226, 'little': 227, 'sick': 228, 'early': 229, 'our': 230, 'two': 231, 'looking': 232, 'left': 233, 'being': 234, 'yay': 235, 'let': 236, "'d": 237, 'wanna': 238, 'few': 239, 'house': 240, 'guys': 241, 'because': 242, 'damn': 243, 'pretty': 244, 'sunday': 245, 'try': 246, 'break': 247, 'help': 248, 'use': 249, 'finally': 250, 'late': 251, 'sucks': 252, 'big': 253, '1': 254, 'missed': 255, 'stuff': 256, 'lost': 257, 'ur': 258, 'things': 259, 'old': 260, 'amazing': 261, 'actually': 262, 'away': 263, 'hours': 264, 'goodnight': 265, 'put': 266, 'other': 267, 'movie': 268, 'before': 269, 'saw': 270, 'luck': 271, 'weeks': 272, 'start': 273, 'same': 274, 'phone': 275, 'read': 276, 'bored': 277, 'guess': 278, 'where': 279, 'wow': 280, 'someone': 281, 'world': 282, 'tell': 283, 'makes': 284, 'sweet': 285, 'omg': 286, '@jonathanrknight': 287, 'those': 288, 'excited': 289, 'god': 290, 'ever': 291, 'forward': 292, 'ready': 293, 'end': 294, 'ugh': 295, 'thought': 296, 'game': 297, 'nothing': 298, 'until': 299, '@': 300, 'such': 301, 'hard': 302, 'friends': 303, 'went': 304, 'music': 305, 'till': 306, '5': 307, 'lot': 308, 'sun': 309, 'bit': 310, 'real': 311, 'yet': 312, 'spring': 313, 'also': 314, 'follow': 315, 'n': 316, 'ta': 317, 'eat': 318, 'aroun ...

# %%
net = WordLSTM().cuda()
train(net, text_train, label_train, batch_size = 32, epochs=20, print_every=4000)
torch.save(net, PATH+'model_tweet_15.pt')
# Out:
# vocab_size  3997
# Epoch: 1/20... Loss: 5.853838...
# Epoch: 2/20... Loss: 5.489911...
# Epoch: 3/20... Loss: 5.182996...
# Epoch: 4/20... Loss: 5.010383...
# Epoch: 5/20... Loss: 4.774088...
# Epoch: 6/20... Loss: 4.627366...
# Epoch: 7/20... Loss: 4.550300...
# Epoch: 8/20... Loss: 4.399261...
# Epoch: 9/20... Loss: 4.253626...
# Epoch: 10/20... Loss: 4.215551...
# Epoch: 11/20... Loss: 4.108526...
# Epoch: 12/20... Loss: 3.989191...
# Epoch: 13/20... Loss: 3.874573...
# Epoch: 14/20... Loss: 3.751858...
# Epoch: 15/20... Loss: 3.615877...
# Epoch: 16/20... Loss: 3.593357...
# Epoch: 17/20... Loss: 3.496465...
# Epoch: 18/20... Loss: 3.368101...
# Epoch: 19/20... Loss: 3.373318...
# Epoch: 20/20... Loss: 3.432022...

# %%
net = torch.load(PATH+'model_tweet_15.pt')
net.eval()
for i in range(10):
    print("Example {} generated: ".format(i))
    print(sample(net, 500, encod, unencod, prime = "<s>"))
# Out:
# Example 0 generated:
# <s> " my _UNK are _UNK , but it is n't a good day . i m scared , i m going for a good day , and i 'm not thinking _UNK i have no _UNK skin i 'm not going for a mini hour or a nice white i have to go back tomorrow . i m scared . hulk get mad . i have n't slept a _UNK - sleep ! ! _UNK . _UNK _UNK , _UNK _UNK _UNK . i 'm _UNK _UNK and _UNK _UNK , but do not wanna eat out , i do nt have enough fun of _UNK and i have a _UNK of my house , and now i 'm going with my _UNK . </s>
# Example 1 generated:
# <s> " i 'm so bad , i 'm scared i ca nt find any this _UNK & lt;3 _UNK ... i 'm scared you were a good night , but i have to get it all over i m _UNK . _UNK _UNK . i 'm going for my house . emotionally in _UNK 's 70 _UNK . _UNK , i m _UNK . my chest is _UNK and it shows up _UNK the _UNK trash to go out of sex wine in _UNK . _UNK i have no idea i ca n't afford to go back to work , but i 'm not thinking by my house .... its like the hills , and now i 'm not too bad ! ! i have to wait insane to get an _UNK necklace to go to the _UNK _UNK this week ! i 'm a bit hot of the _UNK . _UNK i have a virus ... _UNK , i have to get up in my _UNK & amp ; i ca nt find my first anymore or a great white and _UNK - 1 is going back for me ! i 've got my _UNK _UNK in the morning ! ! i have to wait back of my tweet with a car with _UNK , but it was not a great time . i ca n't find @jackgraycnn of my _UNK & quot;the time . _UNK _UNK _UNK . _UNK _UNK _UNK _UNK _UNK ) ) , _UNK . i m going back to school tomorrow . i have no _UNK in the car , and now it was _UNK . _UNK nyte _UNK ! " _UNK i m going to london for my lakers , but it 's going for the sun of my _UNK _UNK , i m not sure why i have n't seen my picture at my lakers and i 'm not going with my life . emotionally of bed to go back tomorrow ... _UNK , i m going with a _UNK show , and it 's _UNK , i 'm scared it was _UNK . i 'm not thinking with a good white . i ca n't get to sleep . it 's 78 of the car , but it was always a nice time , and now no hot than _UNK and i 'm not sick . " i 'm sooo hungry and _UNK for the sudden of _UNK ; & _UNK that not not not been _UNK ; i m _UNK with my house & amp ; they _UNK ; and no nyte ass in capacity tomorrow . it 's _UNK and it 's _UNK and the boys rate and i 'm not sick , but i ca not _UNK the deal _UNK , and now snowing to hear it 's _UNK ! i have n't been _UNK since it was the good idea and it is _UNK ! ! ! ! i m _UNK , i do not wanna eat
# Example 2 generated:
# <s> i ca nt believe i 'm gon _UNK all _UNK _UNK now . i 'm going to sleep tomorrow ... i m not _UNK my _UNK 's not _UNK ; now . </s>
# Example 3 generated:
# <s> _UNK oh _UNK _UNK . i 'm not sick . " i 'm sooo sad but it is been going 2 _UNK from my car . within mac . i 'm not a good night , i m not sure i 'm not too bad . i m not going to find my _UNK necklace of the morning , and i have to go back for my house , but it 's 78 ages on my house . </s>
# Example 4 generated:
# <s> i ca not get @jackgraycnn for the next _UNK in the spanish _UNK in my _UNK . within _UNK _UNK & quot;the _UNK _UNK & _UNK ; not always not _UNK _UNK . i do nt want enough for you guys ! i 'm _UNK _UNK _UNK _UNK _UNK , _UNK , i 'm going for my _UNK in the _UNK , _UNK and the finishing _UNK overall , but it was _UNK , and _UNK , but it 's body i ca not want to get out on my _UNK . within the car ... but there 's _UNK that is n't _UNK _UNK . _UNK _UNK . _UNK , but it was not following the issue and it 's not _UNK my cousins deck , and now no _UNK ... _UNK icky hot . i m not going for my kitchen . it was a _UNK of _UNK , but i 'm going to find the hills , and i have to get a _UNK _UNK this year , i m going for the morning . i m wishin why this break is _UNK _UNK . </s>
# Example 5 generated:
# <s> _UNK i 'm going for a good white and now it is the good way on the _UNK . _UNK now i m not going back . but beer 's _UNK by my _UNK . " _UNK i have n't slept _UNK since i have n't slept any idea so now i do nt get it better ? ? ? ! ! i 'm not thinking too long . it was going for the morning ! </s>
# Example 6 generated:
# <s> i 'm not sure why i 'm too bad and _UNK _UNK _UNK ) _UNK , _UNK . pity . pity , _UNK . no _UNK is a lot of the morning . it is a _UNK _UNK . i 'm _UNK ; _UNK _UNK _UNK . i 'm not sick , but i 'm not sick , and i 'm scared it is _UNK _UNK . i 'm not sick and i have n't been a long fan of _UNK . it was going . i ca nt afford to be _UNK again , i m scared . hulk _UNK . but _UNK is a great time , but do not wanna have bought my picture in _UNK ! i 've been so bad since that s _UNK and the boys came of my poem . _UNK i 'm going to london with me ! ! i 'm pretty thinking i m going for my tweet with my _UNK in _UNK . but it 's going . but _UNK _UNK is _UNK _UNK _UNK _UNK . i m not going back . " i m so hungry and it shows is a singer _UNK , i m going to sleep . i have to get a _UNK ; and _UNK - 1 is _UNK and _UNK * _UNK _UNK * worst _UNK * math * ) i have n't seen my _UNK in the _UNK . i ca n't afford to get an extra performance ! ! i have to go back for my _UNK & _UNK that not not been so _UNK _UNK this week , but it was going to be _UNK but it 's almost _UNK and it 's going for my car . within _UNK but i 'm going with a _UNK _UNK . _UNK _UNK _UNK . i 'm going to find the hills . i m going with a new _UNK of the moment , but it 's 78 degrees than _UNK but it was not going that now it 's _UNK and _UNK _UNK _UNK and i do nt wanna eat out and do n't want to get out of _UNK tomorrow ! </s>
# Example 7 generated:
# <s> _UNK oh _UNK i m going to london . but _UNK is _UNK _UNK . </s>
# Example 8 generated:
# <s> _UNK oh i do nt want 2 sleep . it was going . but i m not thinking out of the morning . it 's 78 in me ! it is a great week ! _UNK i have no idea that now _UNK _UNK ) , i 'm totally _UNK _UNK . _UNK is a _UNK _UNK , but i 'm going for my _UNK _UNK _UNK and _UNK _UNK , _UNK _UNK _UNK , _UNK , i have to be a crazy _UNK skin i have to wait back to bed , i have to go to the _UNK _UNK _UNK and the _UNK rate of _UNK _UNK _UNK ; and children , i have real _UNK skin i 'm going to sleep , but it was going . i ca not afford enough of _UNK ; and i m sooo hungry . _UNK , but i 'm not thinking about the animals to the highway in the morning . </s>
# Example 9 generated:
# <s> i ca nt believe what i 'm going with it tomorrow ! </s>

# %%
## Question 11
net = torch.load(PATH+'model_tweet_15.pt')
net.eval()
test_loss, perplexity = test(net, 'test_2.txt')
print('test loss {:5.2f} | test perplexity {:8.2f}'.format(test_loss.item(), perplexity))
# Out:
# test loss  5.05 | test perplexity   155.99

# %%
## Question 12
net = torch.load(PATH+'model_tweet_5.pt') # best model
net.eval()
test_loss, perplexity = test(net, 'test_1.txt')
print('test loss {:5.2f} | test perplexity {:8.2f}'.format(test_loss.item(), perplexity))
# Out:
# test loss  5.61 | test perplexity   273.83

# %%
## Question 13
max_len_seq =  5 # best model
text_train, label_train, vocab_size, encod, unencod, weights_matrix, words = processing(raw_tweet.copy(), max_len_seq, False, True)
# Out:
# ---- Result after tokenization
# Length words: 12630
# words: Counter({'<s>': 6000, '</s>': 6000, 'i': 3697, '!': 3138, '.': 3088, '"': 2670, 'to': 2281, 'the': 1898, ',': 1897, 'a': 1391, 'it': 1172, 'and': 1132, 'you': 1130, 'my': 1097, 'is': 916, '?': 859, 'in': 854, '...': 828, 'for': 817, 'of': 725, "n't": 678, 'that': 652, 'on': 632, 'have': 623, "'s": 617, 'me': 558, 'so': 534, 'do': 514, 'but': 511, 'just': 463, '-': 457, 'not': 450, "'m": 438, 'was': 431, 'be': 416, 'at': 403, 'with': 385, 'good': 374, 'this': 365, 'now': 357, '..': 354, 'up': 353, ';': 324, '&': 323, 'are': 321, 'all': 318, 'day': 317, 'go': 300, 'out': 295, 'work': 292, 'like': 287, 'get': 277, 'back': 268, 'today': 261, 'time': 257, 'going': 257, 'too': 254, 'got': 253, 'no': 252, 'what': 248, 'we': 247, 'ca': 241, 'your': 234, 'nt': 226, 'love': 222, 'one': 216, 'lol': 213, 'about': 207, 'am': 205, 'know': 195, 'from': 194, 'night': 193, 'will': 187, 'can': 182, 'had': 181, 'if': 181, 'did': 178, 'really': 177, 'tomorrow': 177, 'want': 172, 'well': 171, 'see': 170, 'm': 169, 'some': 169, 'u': 168, 'still': 168, 'its': 165, '2': 161, 'how': 156, 'morning': 156, 'as': 155, 'an': 153, 'oh': 152, 'twitter': 151, 'when': 151, 'more': 148, 'thanks': 147, 'there': 146, "'ll": 143, 'much': 141, 'new': 141, 'then': 140, '....': 140, 'off': 140, "'": 140, 'think': 139, 'need': 138, 'bed': 137, 'they': 137, 'or': 134, 'home': 134, 'amp': 133, 'he': 130, ')': 130, 'again': 130, 'here': 128, 'hope': 128, 'sleep': 128, '(': 127, 'last': 125, 'school': 124, 'feel': 121, 'would': 120, 'only': 118, 'has': 117, ':': 117, 'great': 115, 'does': 113, 'should': 112, 'been': 110, 'miss': 109, "'re": 105, '#': 105, "'ve": 104, 'could': 103, 'haha': 102, 'week': 102, 'very': 101, '*': 101, 'sad': 101, 'over': 100, 'wish': 100, 'nice': 99, 'better': 98, 'days': 98, 'fun': 96, 'come': 95, 'by': 93, 'make': 92, 'why': 92, 'best': 91, 'getting': 90, 'her': 90, 'bad': 89, 'way': 87, 'them': 85, 'please': 84, 'wait': 82, 'next': 82, 'na': 81, 'right': 80, 'who': 80, '/': 79, 'though': 79, 'made': 79, 'happy': 78, 'gon': 78, 'she': 77, 'sorry': 77, 'ok': 77, 'life': 76, 'yes': 76, 'watching': 75, 'long': 74, 'yeah': 72, 'done': 72, 'doing': 71, 'hate': 71, 'weekend': 71, 'take': 70, 'working': 69, 'another': 69, 'than': 67, 'even': 67, 'always': 67, 'hey': 66, '4': 66, 'man': 66, '3': 65, 'find': 64, 'soon': 64, 'trying': 64, 'everyone': 63, 'him': 63, 'already': 63, 's': 63, 'never': 63, 'feeling': 62, 'first': 62, 'maybe': 62, 'us': 62, 'people': 61, 'something': 61, 'show': 60, 'wo': 60, 'down': 60, 'tired': 60, 'thank': 60, 'were': 59, 'say': 59, 'awesome': 59, 'his': 59, 'tonight': 58, 'into': 58, 'cool': 58, 'any': 57, 'glad': 56, 'sure': 55, 'look': 55, '�': 55, 'after': 55, 'having': 54, 'thing': 54, 'keep': 54, 'watch': 53, 'little': 53, 'sick': 52, 'early': 52, 'our': 52, 'two': 51, 'looking': 51, 'left': 51, 'being': 50, 'yay': 50, 'let': 48, "'d": 48, 'wanna': 48, 'few': 48, 'house': 48, 'guys': 47, 'because': 47, 'damn': 47, 'pretty': 47, 'sunday': 47, 'try': 46, 'break': 46, 'help': 45, 'use': 45, 'finally': 44, 'late': 44, 'sucks': 44, 'big': 44, '1': 44, 'missed': 44, 'stuff': 44, 'lost': 43, 'ur': 43, 'things': 43, 'old': 43, 'amazing': 43, 'actually': 43, 'away': 43, 'hours': 42, 'goodnight': 42, 'put': 42, 'other': 42, 'movie': 42, 'before': 42, 'saw': 42, 'luck': 42, 'weeks': 42, 'start': 42, 'same': 41, 'phone': 41, 'read': 41, 'bored': 41, 'guess': 41, 'where': 41, 'wow': 41, 'someone': 41, 'world': 41, 'tell': 40, 'makes': 40, 'sweet': 39, 'omg': 39, '@jonathanrknight': 39, 'those': 39, 'excited': 39, 'god': 39, 'ever': 39, 'forward': 39, 'ready': 39, 'end': 39, 'ugh': 39, 'thought': 38, 'game': 38, 'nothing': 38, 'until': 38, '@': 38, 'such': 38, 'hard': 38, 'friends': 37, 'went': 37, 'music': 37, 'till': 37, '5': 37, 'lot': 37, 'sun': 37, 'bit': 37, 'real': 36, 'yet': 36, 'spring': 36, 'also': 36, 'follow': 36, 'n': 36, 'ta': 36, 'eat': 35, 'around': 35, 'found': 35, 'hear': 35, 'hot': 35, 'check': 35, 'mean ...
# text: [['<s>', 'i', 'love', '@health4uandpets', 'u', 'guys', 'r', 'the', 'best', '!', '!', '</s>'], ['<s>', 'i', 'm', 'meeting', 'up', 'with', 'one', 'of', 'my', 'besties', 'tonight', '!', 'ca', 'nt', 'wait', '!', '!', '-', 'girl', 'talk', '!', '!', '</s>']]
#
# ---- Result after reorganizing by sequences
# text: [['<s>', 'i', 'love', '@health4uandpets', 'u', 'guys'], ['i', 'love', '@health4uandpets', 'u', 'guys', 'r']]
# len(text): 78861
# max_len_seq: 5
# ok
# Word found in glove: 8038/12632
#
# ---- Result after encoding
# text_train: [[2, 4, 66, 3997, 86, 241], [4, 66, 3997, 86, 241, 329]]
#
# ---- Result after padding
# text_train: [[2, 4, 66, 3997, 86, 241], [4, 66, 3997, 86, 241, 329]]
#
# ---- Result after creating x and y
# text_train: [[   2    4   66 3997   86]
#  [   4   66 3997   86  241]]
# label_train: [[   4   66 3997   86  241]
#  [  66 3997   86  241  329]]
# vocab size: 12632

# %%
net = WordLSTM(mode='glove', weights_matrix=weights_matrix).cuda()
train(net, text_train, label_train, batch_size = 32, epochs=20, print_every=4000)
torch.save(net, PATH+'model_tweet_glove_5.pt')
# Out:
# vocab_size  12632
# Epoch: 1/20... Loss: 5.974874...
# Epoch: 2/20... Loss: 5.545497...
# Epoch: 3/20... Loss: 5.121936...
# Epoch: 4/20... Loss: 4.787803...
# Epoch: 5/20... Loss: 4.673324...
# Epoch: 6/20... Loss: 4.471931...
# Epoch: 7/20... Loss: 4.407890...
# Epoch: 8/20... Loss: 4.326817...
# Epoch: 9/20... Loss: 4.154729...
# Epoch: 10/20... Loss: 4.160047...
# Epoch: 11/20... Loss: 4.273318...
# Epoch: 12/20... Loss: 4.265508...
# Epoch: 13/20... Loss: 4.197412...
# Epoch: 14/20... Loss: 4.208659...
# Epoch: 15/20... Loss: 4.113024...
# Epoch: 16/20... Loss: 4.008296...
# Epoch: 17/20... Loss: 3.929439...
# Epoch: 18/20... Loss: 3.944991...
# Epoch: 19/20... Loss: 3.946811...
# Epoch: 20/20... Loss: 3.855349...

# %%
net = torch.load(PATH+'model_tweet_glove_5.pt')
net.eval()
for i in range(10):
    print("Example {} generated: ".format(i))
    print(sample(net, 500, encod, unencod, prime = "<s>"))
# Out:
# Example 0 generated:
# <s> i 'm so sad . </s>
# Example 1 generated:
# <s> " everybody i m so sore , and it is n't n't get any idea , and i 'm so jealous . " i 'm still going for the last of the washing of the rift valley , speeches ! i have n't seen it , and it 's a sad throat , speeches . ihad is n't n't be a long idea to go home to the house . </s>
# Example 2 generated:
# <s> " everybody , it is really good ! i m so sad . </s>
# Example 3 generated:
# <s> i 'm not a closet . </s>
# Example 4 generated:
# <s> is going to see it ! i 'm so tired . </s>
# Example 5 generated:
# <s> i m scared . " i have n't been a virus twilighter . it 's not a great idea to see it ! </s>
# Example 6 generated:
# <s> is not a good idea to see it ! ! i m going to go to school tomorrow </s>
# Example 7 generated:
# <s> " @darealsunisakim oh , that is n't going for the next one of my soul of the show ! i 'm so tired ! ! i 'm so sad , i have n't slept for the cake . i 'm so lucky ! i m stuck up . </s>
# Example 8 generated:
# <s> is going to go home to go to school today , and then i 'm not in a 4hr ! i m not not going to go into my house </s>
# Example 9 generated:
# <s> is not feeling good , and it is not going back to school . </s>

# %%
## Question 14
net = torch.load(PATH+'model_tweet_glove_5.pt') # best model
net.eval()
test_loss, perplexity = test(net, 'test_2.txt')
print('test loss {:5.2f} | test perplexity {:8.2f}'.format(test_loss.item(), perplexity))
# Out:
# test loss  7.54 | test perplexity  1879.76

# %%
## Question 15      GLOVETWITTER
max_len_seq =  5# best model
text_train, label_train, vocab_size, encod, unencod, weights_matrix, words = processing(raw_tweet.copy(), max_len_seq, False, True)
# Out:
# ---- Result after tokenization
# Length words: 12630
# words: Counter({'<s>': 6000, '</s>': 6000, 'i': 3697, '!': 3138, '.': 3088, '"': 2670, 'to': 2281, 'the': 1898, ',': 1897, 'a': 1391, 'it': 1172, 'and': 1132, 'you': 1130, 'my': 1097, 'is': 916, '?': 859, 'in': 854, '...': 828, 'for': 817, 'of': 725, "n't": 678, 'that': 652, 'on': 632, 'have': 623, "'s": 617, 'me': 558, 'so': 534, 'do': 514, 'but': 511, 'just': 463, '-': 457, 'not': 450, "'m": 438, 'was': 431, 'be': 416, 'at': 403, 'with': 385, 'good': 374, 'this': 365, 'now': 357, '..': 354, 'up': 353, ';': 324, '&': 323, 'are': 321, 'all': 318, 'day': 317, 'go': 300, 'out': 295, 'work': 292, 'like': 287, 'get': 277, 'back': 268, 'today': 261, 'time': 257, 'going': 257, 'too': 254, 'got': 253, 'no': 252, 'what': 248, 'we': 247, 'ca': 241, 'your': 234, 'nt': 226, 'love': 222, 'one': 216, 'lol': 213, 'about': 207, 'am': 205, 'know': 195, 'from': 194, 'night': 193, 'will': 187, 'can': 182, 'had': 181, 'if': 181, 'did': 178, 'really': 177, 'tomorrow': 177, 'want': 172, 'well': 171, 'see': 170, 'm': 169, 'some': 169, 'u': 168, 'still': 168, 'its': 165, '2': 161, 'how': 156, 'morning': 156, 'as': 155, 'an': 153, 'oh': 152, 'twitter': 151, 'when': 151, 'more': 148, 'thanks': 147, 'there': 146, "'ll": 143, 'much': 141, 'new': 141, 'then': 140, '....': 140, 'off': 140, "'": 140, 'think': 139, 'need': 138, 'bed': 137, 'they': 137, 'or': 134, 'home': 134, 'amp': 133, 'he': 130, ')': 130, 'again': 130, 'here': 128, 'hope': 128, 'sleep': 128, '(': 127, 'last': 125, 'school': 124, 'feel': 121, 'would': 120, 'only': 118, 'has': 117, ':': 117, 'great': 115, 'does': 113, 'should': 112, 'been': 110, 'miss': 109, "'re": 105, '#': 105, "'ve": 104, 'could': 103, 'haha': 102, 'week': 102, 'very': 101, '*': 101, 'sad': 101, 'over': 100, 'wish': 100, 'nice': 99, 'better': 98, 'days': 98, 'fun': 96, 'come': 95, 'by': 93, 'make': 92, 'why': 92, 'best': 91, 'getting': 90, 'her': 90, 'bad': 89, 'way': 87, 'them': 85, 'please': 84, 'wait': 82, 'next': 82, 'na': 81, 'right': 80, 'who': 80, '/': 79, 'though': 79, 'made': 79, 'happy': 78, 'gon': 78, 'she': 77, 'sorry': 77, 'ok': 77, 'life': 76, 'yes': 76, 'watching': 75, 'long': 74, 'yeah': 72, 'done': 72, 'doing': 71, 'hate': 71, 'weekend': 71, 'take': 70, 'working': 69, 'another': 69, 'than': 67, 'even': 67, 'always': 67, 'hey': 66, '4': 66, 'man': 66, '3': 65, 'find': 64, 'soon': 64, 'trying': 64, 'everyone': 63, 'him': 63, 'already': 63, 's': 63, 'never': 63, 'feeling': 62, 'first': 62, 'maybe': 62, 'us': 62, 'people': 61, 'something': 61, 'show': 60, 'wo': 60, 'down': 60, 'tired': 60, 'thank': 60, 'were': 59, 'say': 59, 'awesome': 59, 'his': 59, 'tonight': 58, 'into': 58, 'cool': 58, 'any': 57, 'glad': 56, 'sure': 55, 'look': 55, '�': 55, 'after': 55, 'having': 54, 'thing': 54, 'keep': 54, 'watch': 53, 'little': 53, 'sick': 52, 'early': 52, 'our': 52, 'two': 51, 'looking': 51, 'left': 51, 'being': 50, 'yay': 50, 'let': 48, "'d": 48, 'wanna': 48, 'few': 48, 'house': 48, 'guys': 47, 'because': 47, 'damn': 47, 'pretty': 47, 'sunday': 47, 'try': 46, 'break': 46, 'help': 45, 'use': 45, 'finally': 44, 'late': 44, 'sucks': 44, 'big': 44, '1': 44, 'missed': 44, 'stuff': 44, 'lost': 43, 'ur': 43, 'things': 43, 'old': 43, 'amazing': 43, 'actually': 43, 'away': 43, 'hours': 42, 'goodnight': 42, 'put': 42, 'other': 42, 'movie': 42, 'before': 42, 'saw': 42, 'luck': 42, 'weeks': 42, 'start': 42, 'same': 41, 'phone': 41, 'read': 41, 'bored': 41, 'guess': 41, 'where': 41, 'wow': 41, 'someone': 41, 'world': 41, 'tell': 40, 'makes': 40, 'sweet': 39, 'omg': 39, '@jonathanrknight': 39, 'those': 39, 'excited': 39, 'god': 39, 'ever': 39, 'forward': 39, 'ready': 39, 'end': 39, 'ugh': 39, 'thought': 38, 'game': 38, 'nothing': 38, 'until': 38, '@': 38, 'such': 38, 'hard': 38, 'friends': 37, 'went': 37, 'music': 37, 'till': 37, '5': 37, 'lot': 37, 'sun': 37, 'bit': 37, 'real': 36, 'yet': 36, 'spring': 36, 'also': 36, 'follow': 36, 'n': 36, 'ta': 36, 'eat': 35, 'around': 35, 'found': 35, 'hear': 35, 'hot': 35, 'check': 35, 'mean ...
# text: [['<s>', 'i', 'love', '@health4uandpets', 'u', 'guys', 'r', 'the', 'best', '!', '!', '</s>'], ['<s>', 'i', 'm', 'meeting', 'up', 'with', 'one', 'of', 'my', 'besties', 'tonight', '!', 'ca', 'nt', 'wait', '!', '!', '-', 'girl', 'talk', '!', '!', '</s>']]
#
# ---- Result after reorganizing by sequences
# text: [['<s>', 'i', 'love', '@health4uandpets', 'u', 'guys'], ['i', 'love', '@health4uandpets', 'u', 'guys', 'r']]
# len(text): 78861
# max_len_seq: 5
# ok
# Word found in glove: 8411/12632
#
# ---- Result after encoding
# text_train: [[2, 4, 66, 3997, 86, 241], [4, 66, 3997, 86, 241, 329]]
#
# ---- Result after padding
# text_train: [[2, 4, 66, 3997, 86, 241], [4, 66, 3997, 86, 241, 329]]
#
# ---- Result after creating x and y
# text_train: [[   2    4   66 3997   86]
#  [   4   66 3997   86  241]]
# label_train: [[   4   66 3997   86  241]
#  [  66 3997   86  241  329]]
# vocab size: 12632

# %%
net = WordLSTM(mode='glove', weights_matrix=weights_matrix).cuda()
train(net, text_train, label_train, batch_size = 32, epochs=20, print_every=4000)
torch.save(net, PATH+'model_tweet_gloveT_5.pt')
# Out:
# vocab_size  12632
# Epoch: 1/20... Loss: 5.840675...
# Epoch: 2/20... Loss: 5.305589...
# Epoch: 3/20... Loss: 5.023337...
# Epoch: 4/20... Loss: 4.863178...
# Epoch: 5/20... Loss: 4.762218...
# Epoch: 6/20... Loss: 4.510095...
# Epoch: 7/20... Loss: 4.485887...
# Epoch: 8/20... Loss: 4.361248...
# Epoch: 9/20... Loss: 4.194154...
# Epoch: 10/20... Loss: 4.096000...
# Epoch: 11/20... Loss: 4.043387...
# Epoch: 12/20... Loss: 3.999984...
# Epoch: 13/20... Loss: 3.885160...
# Epoch: 14/20... Loss: 3.799375...
# Epoch: 15/20... Loss: 3.817178...
# Epoch: 16/20... Loss: 3.816291...
# Epoch: 17/20... Loss: 3.941351...
# Epoch: 18/20... Loss: 3.702725...
# Epoch: 19/20... Loss: 3.619230...
# Epoch: 20/20... Loss: 3.567654...

# %%
net = torch.load(PATH+'model_tweet_gloveT_5.pt')
net.eval()
for i in range(10):
    print("Example {} generated: ".format(i))
    print(sample(net, 500, encod, unencod, prime = "<s>"))
# Out:
# Example 0 generated:
# <s> " @neilhimself yeah i m going back to work , i 'm going back back for school tomorrow , and i m not nominated . otoh i m so lucky i 'm not nominated , but do nt want it , but i 'm f*d ; i 'm not exhausted . i m going to bed . </s>
# Example 1 generated:
# <s> " @mussomitchel i know i could be the problem of a hin . </s>
# Example 2 generated:
# <s> is so sad , i have a doctors weight of the house . </s>
# Example 3 generated:
# <s> " @darealsunisakim yeah , i m so hungry ! " @marsgirl86 @sudeepnayak ! i m going to bed . but ca not comfort coughing . </s>
# Example 4 generated:
# <s> " @mussomitchel yeah , it sucks ! ! </s>
# Example 5 generated:
# <s> is going to be the last day , but it was not a long of the morning ! </s>
# Example 6 generated:
# <s> i hate the boys . </s>
# Example 7 generated:
# <s> " @mussomitchel oh , but do i 'm a closet twilighter , i m so sad i 'm gon na be a good morning . </s>
# Example 8 generated:
# <s> i 'm so sad i m not a sad day , but i do not have to go home . </s>
# Example 9 generated:
# <s> " @mussomitchel yeah i m going back back back to bed </s>

# %%
## Question 16
net = torch.load(PATH+'model_tweet_gloveT_5.pt') # best model
net.eval()
test_loss, perplexity = test(net, 'test_2.txt')
print('test loss {:5.2f} | test perplexity {:8.2f}'.format(test_loss.item(), perplexity))
# Out:
# test loss  7.65 | test perplexity  2108.56

# %%
math.exp(-test_loss)
# Out:
# 0.0004742569062105376

# %% [markdown]
# **PROBLEM 3**

# %%
import re
import csv
import nltk
import numpy as np
nltk.download('punkt')
# torch.cuda.is_available() checks and returns a Boolean True if a GPU is available, else it'll return False
is_cuda = torch.cuda.is_available()
if is_cuda:
    device = torch.device("cuda")
    print("GPU is available")
else:
    device = torch.device("cpu")
    print("GPU not available, CPU used")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# GPU is available

# %%
data_train_complete = pd.read_csv(PATH+'sentiment_complete.csv', encoding = "ISO-8859-1", engine='python', header=None)

# %%
data_train_complete.head()
# Out:
#    0  ...                                                  5
# 0  0  ...  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1  0  ...  is upset that he can't update his Facebook by ...
# 2  0  ...  @Kenichan I dived many times for the ball. Man...
# 3  0  ...    my whole body feels itchy and like its on fire
# 4  0  ...  @nationwideclass no, it's not behaving at all....
#
# [5 rows x 6 columns]

# %%
## LOAD DATA
data_train = pd.read_csv(PATH+'sentiment-train.csv')
data_test = pd.read_csv(PATH+'sentiment-test.csv')
data_train_label = data_train.sentiment 
data_train = data_train.text
data_test_label = data_test.sentiment 
data_test = data_test.text
data_train_complete_label = data_train_complete[0]
data_train_complete = data_train_complete[5]
print("\n---- Preliminary text analysis")
print("Length data_train: {}".format(len(data_train)))
print("Length data_test: {}".format(len(data_test)))
print("Length data_complete: {}".format(len(data_train_complete)))
print("Length data_train_label: {}".format(len(data_train_label)))
print("Length data_test_label: {}".format(len(data_test_label)))
print("Length data_train_complete_label: {}".format(len(data_train_complete_label)))
print("data_train: {}".format(data_train[0]))
print("data_test: {}".format(data_test[0]))
#print("data_train_complete: {}".format(data_train_complete[0]))
# Out:
# ---- Preliminary text analysis
# Length data_train: 60000
# Length data_test: 359
# Length data_complete: 1600000
# Length data_train_label: 60000
# Length data_test_label: 359
# Length data_train_complete_label: 1600000
# data_train: I LOVE @Health4UandPets u guys r the best!!
# data_test: @stellargirl I loooooooovvvvvveee my Kindle2. Not that the DX is cool, but the 2 is fantastic in its own right.

# %%
# Organizing data
train_labels = [x for x in data_train_label]
train_sentences = [x for x in data_train]
test_labels = [x for x in data_test_label]
test_sentences = [x for x in data_test]
# Some simple cleaning of data
for i in range(len(train_sentences)):
    train_sentences[i] = re.sub('\d','0',train_sentences[i])
for i in range(len(test_sentences)):
    test_sentences[i] = re.sub('\d','0',test_sentences[i])
for i in range(len(train_sentences)):
    if 'www.' in train_sentences[i] or 'http:' in train_sentences[i] or 'https:' in train_sentences[i] or '.com' in train_sentences[i]:
        train_sentences[i] = re.sub(r"([^ ]+(?<=\.[a-z]{3}))", "<url>", train_sentences[i])
for i in range(len(test_sentences)):
    if 'www.' in test_sentences[i] or 'http:' in test_sentences[i] or 'https:' in test_sentences[i] or '.com' in test_sentences[i]:
        test_sentences[i] = re.sub(r"([^ ]+(?<=\.[a-z]{3}))", "<url>", test_sentences[i])

print("\n---- Cleaning")
print("Length train_sentences: {}".format(len(train_sentences)))
print("Length train_labels: {}".format(len(train_labels)))
print("Length test_sentences: {}".format(len(test_sentences)))
print("Length test_labels: {}".format(len(test_labels)))
print("data_train: {}".format(train_sentences[0]))
print("data_test: {}".format(test_sentences[0]))

## Preprocessing
words = Counter() #Dictionary that will map a word to the number of times it appeared in all the training sentences
for i, sentence in enumerate(train_sentences):
    train_sentences[i] = [] #The sentences will be stored as a list of words/tokens
    for word in nltk.word_tokenize(sentence): #Tokenizing the words
        words.update([word.lower()]) #Converting all the words to lower case
        train_sentences[i].append(word)

words = {k:v for k,v in words.items() if v>1} # Removing the words that only appear once
words = sorted(words, key=words.get, reverse=True)
words = ['_PAD','_UNK'] + words # Adding padding and unknown to our vocabulary so that they will be assigned an index
word2idx = {o:i for i,o in enumerate(words)}# Dictionaries to store the word to index mappings and vice versa
idx2word = {i:o for i,o in enumerate(words)}
vocab_size = len(word2idx) + 1

for i, sentence in enumerate(train_sentences):
    train_sentences[i] = [word2idx[word] if word in word2idx else word2idx['_UNK'] for word in sentence]
for i, sentence in enumerate(test_sentences):
    test_sentences[i] = [word2idx[word.lower()] if word.lower() in word2idx else word2idx['_UNK'] for word in nltk.word_tokenize(sentence)]

def pad_input(sentences, seq_len):
    features = np.zeros((len(sentences), seq_len),dtype=int)
    for ii, review in enumerate(sentences):
        if len(review) != 0:
            features[ii, -len(review):] = np.array(review)[:seq_len]
    return features

seq_len = 200 #The length that the sentences will be padded/shortened to
train_sentences = pad_input(train_sentences, seq_len)
test_sentences = pad_input(test_sentences, seq_len)

# Converting our labels into numpy arrays
train_labels = np.array(train_labels)
test_labels = np.array(test_labels)

print("\n---- Preprocessing")
print("Length train_sentences: {}".format(len(train_sentences)))
print("Length train_labels: {}".format(len(train_labels)))
print("Length test_sentences: {}".format(len(test_sentences)))
print("Length test_labels: {}".format(len(test_labels)))
#print("data_train: {}".format(train_sentences[0]))
#print("data_test: {}".format(test_sentences[0]))

## Batches
import torch
from torch.utils.data import TensorDataset, DataLoader
train_data = TensorDataset(torch.from_numpy(train_sentences), torch.from_numpy(train_labels))
test_data = TensorDataset(torch.from_numpy(test_sentences), torch.from_numpy(test_labels))
batch_size = 400
batch_size_test = 359
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)
test_loader = DataLoader(test_data, shuffle=True, batch_size=batch_size_test)
dataiter = iter(train_loader)
sample_x, sample_y = dataiter.next()
print(sample_x.shape, sample_y.shape)
# Out:
# ---- Cleaning
# Length train_sentences: 60000
# Length train_labels: 60000
# Length test_sentences: 359
# Length test_labels: 359
# data_train: I LOVE @Health0UandPets u guys r the best!!
# data_test: @stellargirl I loooooooovvvvvveee my Kindle0. Not that the DX is cool, but the 0 is fantastic in its own right.
#
# ---- Preprocessing
# Length train_sentences: 60000
# Length train_labels: 60000
# Length test_sentences: 359
# Length test_labels: 359
# torch.Size([400, 200]) torch.Size([400])

# %%
import torch.nn as nn
output_size = 1
embedding_dim = 400
hidden_dim = 512
n_layers = 2
class SentimentNet(nn.Module):
    def __init__(self, vocab_size, output_size, embedding_dim, hidden_dim, n_layers, drop_prob=0.5, mode='lstm', weights_matrix=[]):
        super(SentimentNet, self).__init__()
        self.output_size = output_size
        self.n_layers = n_layers
        self.hidden_dim = hidden_dim
        self.mode = mode
        self.bidirectional = False
        if weights_matrix != []:
            num_embeddings=weights_matrix.shape[0]
            embedding_dim=weights_matrix.shape[1]
            self.embedding = nn.Embedding(num_embeddings, embedding_dim)
            self.embedding.weight = nn.Parameter(torch.tensor(weights_matrix,dtype=torch.float32))
            self.embedding.weight.requires_grad = False
        else:
            self.embedding = nn.Embedding(vocab_size, embedding_dim)
        if self.mode=='lstm':
            self.unit = nn.LSTM(embedding_dim, hidden_dim, n_layers, dropout=drop_prob, batch_first=True)
        elif self.mode=='blstm':
            self.unit = nn.LSTM(embedding_dim, hidden_dim, n_layers, bidirectional=True, dropout=drop_prob, batch_first=True)
            self.bidirectional = True
        elif self.mode=='gru':
            self.unit = nn.GRU(embedding_dim, hidden_dim, n_layers, dropout=drop_prob, batch_first=True)
        elif self.mode=='bgru':
            self.unit = nn.GRU(embedding_dim, hidden_dim, n_layers, bidirectional=True, dropout=drop_prob, batch_first=True)
            self.bidirectional = True
        self.fc = nn.Linear(hidden_dim, output_size)
        self.dropout = nn.Dropout(0.2)
        self.sigmoid = nn.Sigmoid()
    def forward(self, x, hidden):
        batch_size = x.size(0)
        x = x.long()
        embeds = self.embedding(x)
        unit_out, hidden = self.unit(embeds, hidden)
        unit_out = unit_out.contiguous().view(-1, self.hidden_dim)
        out = self.dropout(unit_out)
        out = self.fc(out)
        out = self.sigmoid(out)
        out = out.view(batch_size, -1)
        out = out[:,-1]
        return out, hidden
    def init_hidden(self, batch_size):
        weight = next(self.parameters()).data
        if self.bidirectional:
            hidden = (weight.new(self.n_layers*2, batch_size, self.hidden_dim).zero_().to(device),
                    weight.new(self.n_layers*2, batch_size, self.hidden_dim).zero_().to(device))
        else:
            hidden = (weight.new(self.n_layers, batch_size, self.hidden_dim).zero_().to(device),
                    weight.new(self.n_layers, batch_size, self.hidden_dim).zero_().to(device))
        if 'gru' in self.mode:
            hidden = hidden[0]
        return hidden

# %%
def train(model, train_loader, mode):
    lr=0.005
    criterion = nn.BCELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    epochs = 5
    clip = 5
    model.train()
    for i in range(epochs):
        h = model.init_hidden(batch_size)
        for inputs, labels in train_loader:
            '''
            you combine the two hidden layers into a tuple. Because of this you cannot use .data. 
            For a GRU you only need one hidden layer not two. So you can either use h1 or h2. 
            You only need two for lstms because it also requires the cell state.
            '''
            if "gru" in mode:
                h = h.data
                h = h.detach()
            else:
                h = tuple([e.data for e in h])
                h = (h[0].detach(),h[1].detach())
            inputs, labels = inputs.to(device), labels.to(device)
            model.zero_grad()
            output, h = model(inputs, h)
            loss = criterion(output.squeeze(), labels.float())
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), clip)
            optimizer.step()
        print("Epoch: {}/{}...".format(i+1, epochs), "Loss: {:.6f}...".format(loss.item()))
    return model

def test(model, test_loader, batch_size_test=359):
    test_losses = []
    num_correct = 0
    criterion = nn.BCELoss()
    h = model.init_hidden(batch_size_test)
    model.eval()
    for inputs, labels in test_loader:
        if "gru" in mode:
            h = h.data
            h = h.detach()
        else:
            h = tuple([e.data for e in h])
            h = (h[0].detach(),h[1].detach())
        inputs, labels = inputs.to(device), labels.to(device)
        #print(inputs.size())
        output, h = model(inputs, h)
        test_loss = criterion(output.squeeze(), labels.float())
        test_losses.append(test_loss.item())
        pred = torch.round(output.squeeze()) #rounds the output to 0/1
        correct_tensor = pred.eq(labels.float().view_as(pred))
        correct = np.squeeze(correct_tensor.cpu().numpy())
        num_correct += np.sum(correct)
    return test_losses, num_correct

# %%
## Question 1
mode = 'lstm'
model = SentimentNet(vocab_size, output_size, embedding_dim, hidden_dim, n_layers, mode=mode)
model.to(device)
print(model)
# Out:
# SentimentNet(
#   (embedding): Embedding(19960, 400)
#   (unit): LSTM(400, 512, num_layers=2, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (sigmoid): Sigmoid()
# )

# %%
## Train model
model = train(model, train_loader, mode)
torch.save(model, PATH+'model_class_lstm.pt')

# %%
model = torch.load(PATH+'model_class_lstm.pt')
test_losses, num_correct = test(model, test_loader)
test_acc = num_correct/len(test_loader.dataset)        
print("Test loss: {:.3f}".format(np.mean(test_losses)))
print("Test accuracy: {:.3f}%".format(test_acc*100))
# Out:
# Test loss: 0.745
# Test accuracy: 74.373%

# %%
## Question 2
mode='gru'
model = SentimentNet(vocab_size, output_size, embedding_dim, hidden_dim, n_layers, mode=mode)
model.to(device)
print(model)
# Out:
# SentimentNet(
#   (embedding): Embedding(19960, 400)
#   (unit): GRU(400, 512, num_layers=2, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (sigmoid): Sigmoid()
# )

# %%
model = train(model, train_loader, mode)
torch.save(model, PATH+'model_class_gru.pt')

# %%
model = torch.load(PATH+'model_class_gru.pt')
test_losses, num_correct = test(model, test_loader)
test_acc = num_correct/len(test_loader.dataset)        
print("Test loss: {:.3f}".format(np.mean(test_losses)))
print("Test accuracy: {:.3f}%".format(test_acc*100))
# Out:
# Test loss: 0.555
# Test accuracy: 76.880%

# %%
## Question 3
mode='blstm'
model = SentimentNet(vocab_size, output_size, embedding_dim, hidden_dim, n_layers, mode=mode)
model.to(device)
print(model)
# Out:
# SentimentNet(
#   (embedding): Embedding(19960, 400)
#   (unit): LSTM(400, 512, num_layers=2, batch_first=True, dropout=0.5, bidirectional=True)
#   (fc): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (sigmoid): Sigmoid()
# )

# %%
model = train(model, train_loader, mode)
torch.save(model, PATH+'model_class_blstm.pt')
# Out:
# Epoch: 1/5... Loss: 0.526390...
# Epoch: 2/5... Loss: 0.481762...
# Epoch: 3/5... Loss: 0.402982...
# Epoch: 4/5... Loss: 0.356812...
# Epoch: 5/5... Loss: 0.315888...

# %%
model = torch.load(PATH+'model_class_blstm.pt')
test_losses, num_correct = test(model, test_loader)
test_acc = num_correct/len(test_loader.dataset)        
print("Test loss: {:.3f}".format(np.mean(test_losses)))
print("Test accuracy: {:.3f}%".format(test_acc*100))
# Out:
# Test loss: 0.624
# Test accuracy: 77.716%

# %%
## Question 4
mode='bgru'
model = SentimentNet(vocab_size, output_size, embedding_dim, hidden_dim, n_layers, mode=mode)
model.to(device)
print(model)
# Out:
# SentimentNet(
#   (embedding): Embedding(19960, 400)
#   (unit): GRU(400, 512, num_layers=2, batch_first=True, dropout=0.5, bidirectional=True)
#   (fc): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (sigmoid): Sigmoid()
# )

# %%
model = train(model, train_loader, mode)
torch.save(model, PATH+'model_class_bgru.pt')
# Out:
# Epoch: 1/5... Loss: 0.479517...
# Epoch: 2/5... Loss: 0.439087...
# Epoch: 3/5... Loss: 0.399345...
# Epoch: 4/5... Loss: 0.400972...
# Epoch: 5/5... Loss: 0.421475...

# %%
model = torch.load(PATH+'model_class_bgru.pt')
test_losses, num_correct = test(model, test_loader)
test_acc = num_correct/len(test_loader.dataset)        
print("Test loss: {:.3f}".format(np.mean(test_losses)))
print("Test accuracy: {:.3f}%".format(test_acc*100))
# Out:
# Test loss: 0.650
# Test accuracy: 75.209%

# %%
## Question 5
def encode_glove(words):
    ## Create glove structure from file
    glove = {}
    with open(PATH+'glove.twitter.27B.100d.txt') as f:
        for line in f:
            values = line.split()
            word = values[0]
            vector = np.asarray(values[1:], "float32")
            glove[word] = vector
    for el in ['_PAD','_UNK']:
        glove[el] = np.random.normal(scale=0.6, size=(100, )) #np.random.rand(100)
    ## Create embedding matrix for nn (based on the words in the vocab)
    matrix_len = len(words)
    weights_matrix = np.zeros((matrix_len, 100))
    words_found = 0
    for i, word in enumerate(words):
        try: 
            weights_matrix[i] = glove[word]
            words_found += 1
        except KeyError:
            weights_matrix[i] = np.random.normal(scale=0.6, size=(100, )) #np.random.rand(100)
    print("Word found in glove: {}/{}".format(words_found,matrix_len))
    return weights_matrix, glove

weights_matrix, glove = encode_glove(words)
vocab_size = len(weights_matrix)
# Out:
# Word found in glove: 86782/247693

# %%
mode = 'blstm'
model = SentimentNet(vocab_size, output_size, embedding_dim, hidden_dim, n_layers, mode=mode, weights_matrix=weights_matrix)
model.to(device)
print(model)
# Out:
# SentimentNet(
#   (embedding): Embedding(19959, 100)
#   (unit): LSTM(100, 512, num_layers=2, batch_first=True, dropout=0.5, bidirectional=True)
#   (fc): Linear(in_features=512, out_features=1, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (sigmoid): Sigmoid()
# )
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.

# %%
model = train(model, train_loader, mode)
torch.save(model, PATH+'model_class_blstm_glove.pt')
# Out:
# Epoch: 1/5... Loss: 0.549527...
# Epoch: 2/5... Loss: 0.515563...
# Epoch: 3/5... Loss: 0.479801...
# Epoch: 4/5... Loss: 0.476016...
# Epoch: 5/5... Loss: 0.494489...

# %%
model = torch.load(PATH+'model_class_blstm_glove.pt')
test_losses, num_correct = test(model, test_loader)
test_acc = num_correct/len(test_loader.dataset)        
print("Test loss: {:.3f}".format(np.mean(test_losses)))
print("Test accuracy: {:.3f}%".format(test_acc*100))
# Out:
# Test loss: 0.452
# Test accuracy: 79.666%

# %%
## Question 6 
mode = 'blstm'
from sklearn.model_selection import KFold
kfold = KFold(n_splits=5, shuffle=True)

# %%
# K-fold Cross Validation model evaluation
for emb, hid in zip([100, 100, 400, 400], [128, 512, 128, 512]):
  print(f'------- embedding_dim={embedding_dim}, hidden_dim={hidden_dim}')
  embedding_dim = emb
  hidden_dim = hid
  avg = 0
  for fold, (train_ids, test_ids) in enumerate(kfold.split(train_data)):
    print(f'--- FOLD {fold}')
    # Init
    model = SentimentNet(vocab_size, output_size, embedding_dim, hidden_dim, n_layers, mode=mode, weights_matrix=weights_matrix)
    model.to(device)

    # Sample elements randomly from a given list of ids, no replacement.
    train_subsampler = torch.utils.data.SubsetRandomSampler(train_ids)
    test_subsampler = torch.utils.data.SubsetRandomSampler(test_ids)
    
    # Define data loaders for training and testing data in this fold
    train_sub_loader = torch.utils.data.DataLoader(train_data, batch_size=400, sampler=train_subsampler)
    test_sub_loader = torch.utils.data.DataLoader(train_data, batch_size=400, sampler=test_subsampler)
    
    model = train(model, train_sub_loader, mode)
    test_losses, num_correct = test(model, test_sub_loader, batch_size_test=400)
    test_acc = num_correct/len(test_subsampler)      
    avg += test_acc  
    #print("Test loss: {:.3f}".format(np.mean(test_losses)))
    print("Test accuracy: {:.3f}%".format(test_acc*100))
  print("Test avg fold accuracy: {:.3f}%".format((avg/5)*100))
# Out:
# ------- embedding_dim=100, hidden_dim=128
# --- FOLD 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
# Epoch: 1/5... Loss: 0.487306...
# Epoch: 2/5... Loss: 0.464413...
# Epoch: 3/5... Loss: 0.516506...
# Epoch: 4/5... Loss: 0.401988...
# Epoch: 5/5... Loss: 0.417240...
# Test accuracy: 77.758%
# --- FOLD 1
# Epoch: 1/5... Loss: 0.534377...
# Epoch: 2/5... Loss: 0.431462...
# Epoch: 3/5... Loss: 0.466414...
# Epoch: 4/5... Loss: 0.446498...
# Epoch: 5/5... Loss: 0.424405...
# Test accuracy: 77.917%
# --- FOLD 2
# Epoch: 1/5... Loss: 0.560606...
# Epoch: 2/5... Loss: 0.511217...
# Epoch: 3/5... Loss: 0.422498...
# Epoch: 4/5... Loss: 0.481465...
# Epoch: 5/5... Loss: 0.399270...
# Test accuracy: 77.433%
# --- FOLD 3
# Epoch: 1/5... Loss: 0.506984...
# Epoch: 2/5... Loss: 0.505783...
# Epoch: 3/5... Loss: 0.440371...
# Epoch: 4/5... Loss: 0.461741...
# Epoch: 5/5... Loss: 0.442439...
# Test accuracy: 78.117%
# --- FOLD 4
# Epoch: 1/5... Loss: 0.566215...
# Epoch: 2/5... Loss: 0.501004...
# Epoch: 3/5... Loss: 0.457864...
# Epoch: 4/5... Loss: 0.469962...
# Epoch: 5/5... Loss: 0.397017...
# Test accuracy: 77.775%
# Test avg fold accuracy: 77.800%
# ------- embedding_dim=100, hidden_dim=128
# --- FOLD 0
# Epoch: 1/5... Loss: 0.774404...
# Epoch: 2/5... Loss: 0.513837...
# Epoch: 3/5... Loss: 0.523486...
# Epoch: 4/5... Loss: 0.486648...
# Epoch: 5/5... Loss: 0.453729...
# Test accuracy: 77.450%
# --- FOLD 1
# Epoch: 1/5... Loss: 0.556154...
# Epoch: 2/5... Loss: 0.472607...
# Epoch: 3/5... Loss: 0.453779...
# Epoch: 4/5... Loss: 0.455151...
# Epoch: 5/5... Loss: 0.378811...
# Test accuracy: 77.558%
# --- FOLD 2
# Epoch: 1/5... Loss: 0.520397...
# Epoch: 2/5... Loss: 0.548604...
# Epoch: 3/5... Loss: 0.484073...
# Epoch: 4/5... Loss: 0.430066...
# Epoch: 5/5... Loss: 0.398280...
# Test accuracy: 77.475%
# --- FOLD 3
# Epoch: 1/5... Loss: 0.541704...
# Epoch: 2/5... Loss: 0.486990...
# Epoch: 3/5... Loss: 0.525073...
# Epoch: 4/5... Loss: 0.442767...
# Epoch: 5/5... Loss: 0.396256...
# Test accuracy: 77.792%
# --- FOLD 4
# Epoch: 1/5... Loss: 0.521643...
# Epoch: 2/5... Loss: 0.507405...
# Epoch: 3/5... Loss: 0.467219...
# Epoch: 4/5... Loss: 0.428882...
# Epoch: 5/5... Loss: 0.421031...
# Test accuracy: 77.592%
# Test avg fold accuracy: 77.573%
# ------- embedding_dim=100, hidden_dim=512
# --- FOLD 0
# Epoch: 1/5... Loss: 0.480742...
# Epoch: 2/5... Loss: 0.477654...
# Epoch: 3/5... Loss: 0.472239...
# Epoch: 4/5... Loss: 0.435017...
# Epoch: 5/5... Loss: 0.405484...
# Test accuracy: 78.475%
# --- FOLD 1
# Epoch: 1/5... Loss: 0.479520...
# Epoch: 2/5... Loss: 0.493086...
# Epoch: 3/5... Loss: 0.419266...
# Epoch: 4/5... Loss: 0.438550...
# Epoch: 5/5... Loss: 0.461740...
# Test accuracy: 78.158%
# --- FOLD 2
# Epoch: 1/5... Loss: 0.485271...
# Epoch: 2/5... Loss: 0.497703...
# Epoch: 3/5... Loss: 0.473990...
# Epoch: 4/5... Loss: 0.436104...
# Epoch: 5/5... Loss: 0.369319...
# Test accuracy: 78.083%
# --- FOLD 3
# Epoch: 1/5... Loss: 0.549724...
# Epoch: 2/5... Loss: 0.534272...
# Epoch: 3/5... Loss: 0.452892...
# Epoch: 4/5... Loss: 0.466564...
# Epoch: 5/5... Loss: 0.432293...
# Test accuracy: 77.250%
# --- FOLD 4
# Epoch: 1/5... Loss: 0.494747...
# Epoch: 2/5... Loss: 0.498369...
# Epoch: 3/5... Loss: 0.447763...
# Epoch: 4/5... Loss: 0.444830...
# Epoch: 5/5... Loss: 0.430064...
# Test accuracy: 77.467%
# Test avg fold accuracy: 77.887%
# ------- embedding_dim=400, hidden_dim=128
# --- FOLD 0
# Epoch: 1/5... Loss: 0.541959...
# Epoch: 2/5... Loss: 0.483773...
# Epoch: 3/5... Loss: 0.483449...
# Epoch: 4/5... Loss: 0.449374...
# Epoch: 5/5... Loss: 0.441148...
# Test accuracy: 77.250%
# --- FOLD 1
# Epoch: 1/5... Loss: 0.528021...
# Epoch: 2/5... Loss: 0.464070...
# Epoch: 3/5... Loss: 0.524046...
# Epoch: 4/5... Loss: 0.422538...
# Epoch: 5/5... Loss: 0.326744...
# Test accuracy: 78.325%
# --- FOLD 2
# Epoch: 1/5... Loss: 0.529332...
# Epoch: 2/5... Loss: 0.531657...
# Epoch: 3/5... Loss: 0.463360...
# Epoch: 4/5... Loss: 0.429179...
# Epoch: 5/5... Loss: 0.433305...
# Test accuracy: 77.367%
# --- FOLD 3
# Epoch: 1/5... Loss: 0.516714...
# Epoch: 2/5... Loss: 0.423221...
# Epoch: 3/5... Loss: 0.463000...
# Epoch: 4/5... Loss: 0.435286...
# Epoch: 5/5... Loss: 0.464220...
# Test accuracy: 77.683%
# --- FOLD 4
# Epoch: 1/5... Loss: 0.696122...
# Epoch: 2/5... Loss: 0.666934...
# Epoch: 3/5... Loss: 0.541213...
# Epoch: 4/5... Loss: 0.493369...
# Epoch: 5/5... Loss: 0.515996...
# Test accuracy: 76.433%
# Test avg fold accuracy: 77.412%

# %%
## Question 7
mode = 'blstm'
embedding_dim = 400
hidden_dim = 128
model = SentimentNet(vocab_size, output_size, embedding_dim, hidden_dim, n_layers, mode=mode, weights_matrix=weights_matrix)
model.to(device)
print(model)
# Out:
# SentimentNet(
#   (embedding): Embedding(19959, 100)
#   (unit): LSTM(100, 128, num_layers=2, batch_first=True, dropout=0.5, bidirectional=True)
#   (fc): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (sigmoid): Sigmoid()
# )
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.

# %%
model = train(model, train_loader, mode)
torch.save(model, PATH+'model_class_best.pt')
# Out:
# Epoch: 1/5... Loss: 0.500725...
# Epoch: 2/5... Loss: 0.523367...
# Epoch: 3/5... Loss: 0.477262...
# Epoch: 4/5... Loss: 0.412091...
# Epoch: 5/5... Loss: 0.440028...

# %%
model = torch.load(PATH+'model_class_best.pt')
test_losses, num_correct = test(model, test_loader)
test_acc = num_correct/len(test_loader.dataset)        
print("Test loss: {:.3f}".format(np.mean(test_losses)))
print("Test accuracy: {:.3f}%".format(test_acc*100))
# Out:
# Test loss: 0.427
# Test accuracy: 80.501%

# %%
## Question 8
# Organizing data
train_labels_raw = [x for x in data_train_complete_label]
train_sentences_raw = [x for x in data_train_complete]
test_labels = [x for x in data_test_label]
test_sentences = [x for x in data_test]

train_labels = []
train_sentences = []
# eliminate all neutral labels
for sent, label in zip(train_sentences_raw, train_labels_raw):
    if label == 2:
      continue
    elif label == 4:
      label = 1
    train_labels.append(label)
    train_sentences.append(sent)
    

# Some simple cleaning of data
for i in range(len(train_sentences)):
    train_sentences[i] = re.sub('\d','0',train_sentences[i])
for i in range(len(test_sentences)):
    test_sentences[i] = re.sub('\d','0',test_sentences[i])
for i in range(len(train_sentences)):
    if 'www.' in train_sentences[i] or 'http:' in train_sentences[i] or 'https:' in train_sentences[i] or '.com' in train_sentences[i]:
        train_sentences[i] = re.sub(r"([^ ]+(?<=\.[a-z]{3}))", "<url>", train_sentences[i])
for i in range(len(test_sentences)):
    if 'www.' in test_sentences[i] or 'http:' in test_sentences[i] or 'https:' in test_sentences[i] or '.com' in test_sentences[i]:
        test_sentences[i] = re.sub(r"([^ ]+(?<=\.[a-z]{3}))", "<url>", test_sentences[i])

print("\n---- Cleaning")
print("Length train_sentences: {}".format(len(train_sentences)))
print("Length train_labels: {}".format(len(train_labels)))
print("Length test_sentences: {}".format(len(test_sentences)))
print("Length test_labels: {}".format(len(test_labels)))
print("data_train: {}".format(train_sentences[0]))
print("data_test: {}".format(test_sentences[0]))

## Preprocessing
words = Counter() #Dictionary that will map a word to the number of times it appeared in all the training sentences
for i, sentence in enumerate(train_sentences):
    train_sentences[i] = [] #The sentences will be stored as a list of words/tokens
    for word in nltk.word_tokenize(sentence): #Tokenizing the words
        words.update([word.lower()]) #Converting all the words to lower case
        train_sentences[i].append(word)

words = {k:v for k,v in words.items() if v>1} # Removing the words that only appear once
words = sorted(words, key=words.get, reverse=True)
words = ['_PAD','_UNK'] + words # Adding padding and unknown to our vocabulary so that they will be assigned an index
word2idx = {o:i for i,o in enumerate(words)}# Dictionaries to store the word to index mappings and vice versa
idx2word = {i:o for i,o in enumerate(words)}
vocab_size = len(word2idx) + 1

for i, sentence in enumerate(train_sentences):
    train_sentences[i] = [word2idx[word] if word in word2idx else word2idx['_UNK'] for word in sentence]
for i, sentence in enumerate(test_sentences):
    test_sentences[i] = [word2idx[word.lower()] if word.lower() in word2idx else word2idx['_UNK'] for word in nltk.word_tokenize(sentence)]

def pad_input(sentences, seq_len):
    features = np.zeros((len(sentences), seq_len),dtype=int)
    for ii, review in enumerate(sentences):
        if len(review) != 0:
            features[ii, -len(review):] = np.array(review)[:seq_len]
    return features

seq_len = 200 #The length that the sentences will be padded/shortened to
train_sentences = pad_input(train_sentences, seq_len)
test_sentences = pad_input(test_sentences, seq_len)

# Converting our labels into numpy arrays
train_labels = np.array(train_labels)
test_labels = np.array(test_labels)

print("\n---- Preprocessing")
print("Length train_sentences: {}".format(len(train_sentences)))
print("Length train_labels: {}".format(len(train_labels)))
print("Length test_sentences: {}".format(len(test_sentences)))
print("Length test_labels: {}".format(len(test_labels)))
#print("data_train: {}".format(train_sentences[0]))
#print("data_test: {}".format(test_sentences[0]))

## Batches
import torch
from torch.utils.data import TensorDataset, DataLoader
train_data = TensorDataset(torch.from_numpy(train_sentences), torch.from_numpy(train_labels))
test_data = TensorDataset(torch.from_numpy(test_sentences), torch.from_numpy(test_labels))
batch_size = 400
batch_size_test = 359
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)
test_loader = DataLoader(test_data, shuffle=True, batch_size=batch_size_test)
dataiter = iter(train_loader)
sample_x, sample_y = dataiter.next()
print(sample_x.shape, sample_y.shape)
# Out:
# ---- Cleaning
# Length train_sentences: 1600000
# Length train_labels: 1600000
# Length test_sentences: 359
# Length test_labels: 359
# data_train: @switchfoot <url>/0y0zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D
# data_test: @stellargirl I loooooooovvvvvveee my Kindle0. Not that the DX is cool, but the 0 is fantastic in its own right.
#
# ---- Preprocessing
# Length train_sentences: 1600000
# Length train_labels: 1600000
# Length test_sentences: 359
# Length test_labels: 359
# torch.Size([400, 200]) torch.Size([400])

# %%
for sent, label in zip(train_sentences_raw, train_labels_raw):
    if label == 2:
      print('ok')
      break
      continue
    elif label == 4:
      label = 1

# %%
mode = 'blstm'
embedding_dim = 400
hidden_dim = 128
model = SentimentNet(vocab_size, output_size, embedding_dim, hidden_dim, n_layers, mode=mode, weights_matrix=weights_matrix)
model.to(device)
print(model)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
# SentimentNet(
#   (embedding): Embedding(247693, 100)
#   (unit): LSTM(100, 128, num_layers=2, batch_first=True, dropout=0.5, bidirectional=True)
#   (fc): Linear(in_features=128, out_features=1, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (sigmoid): Sigmoid()
# )

# %%
model = train(model, train_loader, mode)
torch.save(model, PATH+'model_class_best_complete.pt')
# Out:
# Epoch: 1/5... Loss: 0.424559...
# Epoch: 2/5... Loss: 0.431419...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-a0702d2800ed> in <module>()
# ----> 1 model = train(model, train_loader, mode)
#       2 torch.save(model, PATH+'model_class_best_complete.pt')
#
# <ipython-input-17-ef75aab97806> in train(model, train_loader, mode)
#      25             loss = criterion(output.squeeze(), labels.float())
#      26             loss.backward()
# ---> 27             nn.utils.clip_grad_norm_(model.parameters(), clip)
#      28             optimizer.step()
#      29         print("Epoch: {}/{}...".format(i+1, epochs), "Loss: {:.6f}...".format(loss.item()))
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/utils/clip_grad.py in clip_grad_norm_(parameters, max_norm, norm_type)
#      36         total_norm = torch.norm(torch.stack([torch.norm(p.grad.detach(), norm_type).to(device) for p in parameters]), norm_type)
#      37     clip_coef = max_norm / (total_norm + 1e-6)
# ---> 38     if clip_coef < 1:
#      39         for p in parameters:
#      40             p.grad.detach().mul_(clip_coef.to(p.grad.device))
#
# KeyboardInterrupt:

# %%
#model = torch.load(PATH+'model_class_best_complete.pt')
test_losses, num_correct = test(model, test_loader)
test_acc = num_correct/len(test_loader.dataset)        
print("Test loss: {:.3f}".format(np.mean(test_losses)))
print("Test accuracy: {:.3f}%".format(test_acc*100))
# Out:
# Test loss: 0.355
# Test accuracy: 83.565%
